# %%
import numpy as np
import pandas as pd

# %%
main = pd.read_csv('main.csv')

# %%
main.shape
# Out:
# (1932, 443)

# %%
##list(main)

# %%
group_data = main.groupby('redcap_event_name')[['id_participant']].count()
group_data
# Out:
#                           id_participant
# redcap_event_name
# consent_initial_vi_arm_1             834
# consent_initial_vi_arm_2              72
# sample_a_year_1_arm_1                303
# sample_a_year_2_arm_1                 73
# sample_b_year_1_arm_1                149
# sample_b_year_2_arm_1                 12
# sample_c_year_1_arm_1                  2
# sample_d_year_1_arm_1                  1
# year_1_arm_1                         452
# year_1a_arm_2                         30
# year_2_arm_2                           4

# %%
list_events = main['redcap_event_name'].unique()
list_events
# Out:
# array(['consent_initial_vi_arm_1', 'year_1_arm_1',
#        'sample_a_year_1_arm_1', 'sample_b_year_1_arm_1',
#        'sample_a_year_2_arm_1', 'sample_b_year_2_arm_1',
#        'sample_c_year_1_arm_1', 'consent_initial_vi_arm_2',
#        'year_1a_arm_2', 'year_2_arm_2', 'sample_d_year_1_arm_1'],
#       dtype=object)

# %%
for event in list_events:
    data = main[main['redcap_event_name'] == event]
    data.to_csv(event + ".csv")

# %%
consent_files = [x for x in list_events if 'consent_initial' in x]
consent_files
# Out:
# ['consent_initial_vi_arm_1', 'consent_initial_vi_arm_2']

# %%
for event in list_events:
    data = main[main['redcap_event_name'] == event]
    data.to_csv(event + ".csv")
    
consent_files = [x for x in list_events if 'consent_initial' in x]

for f in consent_files:
    arm = pd.read_csv(f + ".csv")
    arm_type = f.split('vi_')[-1]
    arm_files = [x for x in list_events if arm_type in x]
    for subfile in arm_files:
        sub =  pd.read_csv(subfile + ".csv")
        print(sub.shape)
        print(sub.isnull().sum())
        sub.set_index('id_participant', inplace=True)
        sub.update(arm.set_index('id_participant'),overwrite=False)
        sub.reset_index()
        sub.to_csv(subfile + ".csv")
# Out:
# (834, 444)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                         2
# name_middle                      355
# name_last                          2
# dob                                5
# id_primary                         5
# id_secondary                     793
# id_imsms                         788
# id_med_record_number              32
# subject_group                     11
# recruitment_source                 4
# recruitment_source_other         725
# enrollment_site                    6
# other_enrollment                 771
# msdx_recruitment                  20
# msdx_current                      26
# medical_release                  784
# msdx_validated                   108
# msdx_validated_upload            825
# date_firstsx                     161
# age_firstsx                      179
# type_firstsx                     250
# date_msdx                         96
# ...

# %%
arm1 = pd.read_csv("consent_initial_vi_arm_1.csv")

# %%
arm1.shape
# Out:
# (834, 444)

# %%
arm1.isnull().sum()
# Out:
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                         2
# name_middle                      355
# name_last                          2
# dob                                5
# id_primary                         5
# id_secondary                     793
# id_imsms                         788
# id_med_record_number              32
# subject_group                     11
# recruitment_source                 4
# recruitment_source_other         725
# enrollment_site                    6
# other_enrollment                 771
# msdx_recruitment                  20
# msdx_current                      26
# medical_release                  784
# msdx_validated                   108
# msdx_validated_upload            825
# date_firstsx                     161
# age_firstsx                      179
# type_firstsx                     250
# date_msdx                         96
# ...

# %%
arm1_files = [x for x in list_events if 'arm_1' in x]
arm1_files
# Out:
# ['consent_initial_vi_arm_1',
#  'year_1_arm_1',
#  'sample_a_year_1_arm_1',
#  'sample_b_year_1_arm_1',
#  'sample_a_year_2_arm_1',
#  'sample_b_year_2_arm_1',
#  'sample_c_year_1_arm_1',
#  'sample_d_year_1_arm_1']

# %%
s1 = pd.read_csv('sample_a_year_1_arm_1.csv')

# %%
s1.head()
# Out:
#    Unnamed: 0 id_participant      redcap_event_name  name_first  name_middle  \
# 0           2      PRT170001  sample_a_year_1_arm_1         NaN          NaN
# 1           8      PRT170003  sample_a_year_1_arm_1         NaN          NaN
# 2          12      PRT170004  sample_a_year_1_arm_1         NaN          NaN
# 3          19      PRT170007  sample_a_year_1_arm_1         NaN          NaN
# 4          24      PRT170008  sample_a_year_1_arm_1         NaN          NaN
#
#    name_last  dob  id_primary  id_secondary  id_imsms           ...            \
# 0        NaN  NaN         NaN           NaN       NaN           ...
# 1        NaN  NaN         NaN           NaN       NaN           ...
# 2        NaN  NaN         NaN           NaN       NaN           ...
# 3        NaN  NaN         NaN           NaN       NaN           ...
# 4        NaN  NaN         NaN           NaN       NaN           ...
#
#    mri_date_mail_sent  mri_date_signed_consent  mri_version_consent_form  \
# ...

# %%
s1.shape
# Out:
# (303, 444)

# %%
s1.isnull().sum()
# Out:
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       303
# name_middle                      303
# name_last                        303
# dob                              303
# id_primary                       303
# id_secondary                     303
# id_imsms                         303
# id_med_record_number             303
# subject_group                    303
# recruitment_source               303
# recruitment_source_other         303
# enrollment_site                  303
# other_enrollment                 303
# msdx_recruitment                 303
# msdx_current                     303
# medical_release                  303
# msdx_validated                   303
# msdx_validated_upload            303
# date_firstsx                     303
# age_firstsx                      303
# type_firstsx                     303
# date_msdx                        303
# ...

# %%
main1 = arm1.dropna(axis=1)

# %%
main1.shape
# Out:
# (834, 34)

# %%
main1.describe()
# Out:
#         Unnamed: 0  method_msdx___1  method_msdx___2  method_msdx___3  \
# count   834.000000       834.000000       834.000000       834.000000
# mean   1087.748201         0.425659         0.636691         0.490408
# std     559.745905         0.494739         0.481241         0.500208
# min       0.000000         0.000000         0.000000         0.000000
# 25%     628.750000         0.000000         0.000000         0.000000
# 50%    1120.000000         0.000000         1.000000         0.000000
# 75%    1595.500000         1.000000         1.000000         1.000000
# max    1931.000000         1.000000         1.000000         1.000000
#
#        method_msdx___4  dmt_current___1  dmt_current___2  dmt_current___3  \
# count       834.000000       834.000000       834.000000       834.000000
# mean          0.068345         0.007194         0.070743         0.009592
# std           0.252489         0.084564         0.256550         0.097528
# ...

# %%
temp1 = s1.dropna(axis=1)

# %%
temp1.shape
# Out:
# (303, 8)

# %%
temp1.describe()
# Out:
#         Unnamed: 0  blood_sample_complete  stool_sample_complete  \
# count   303.000000             303.000000              303.00000
# mean    889.115512               1.755776                0.60066
# std     533.347181               0.655914                0.91832
# min       2.000000               0.000000                0.00000
# 25%     415.000000               2.000000                0.00000
# 50%     844.000000               2.000000                0.00000
# 75%    1362.000000               2.000000                2.00000
# max    1921.000000               2.000000                2.00000
#
#        urine_sample_complete  saliva_sample_complete  t_mri_complete
# count                  303.0                   303.0      303.000000
# mean                     0.0                     0.0        0.112211
# std                      0.0                     0.0        0.461012
# min                      0.0                     0.0        0.000000
# ...

# %%
arm1[arm1['id_participant']=='PRT170001']
# Out:
#    Unnamed: 0 id_participant         redcap_event_name name_first name_middle  \
# 0           0      PRT170001  consent_initial_vi_arm_1       Amar         NaN
#
#     name_last         dob id_primary id_secondary id_imsms  \
# 0  Shiwlochan  1993-01-14  PRT170001          NaN      NaN
#
#             ...           mri_date_mail_sent  mri_date_signed_consent  \
# 0           ...                          NaN                      NaN
#
#    mri_version_consent_form mri_version_date_consent_form  mri_consent_pdf  \
# 0                       NaN                           NaN              NaN
#
#   t_mri_complete  tdate_order  tdate_completion  notes_3t  \
# 0            NaN          NaN               NaN       NaN
#
#    subtle_3t_mri_complete
# 0                     0.0
#
# [1 rows x 444 columns]

# %%
s1.set_index('id_participant', inplace=True)
s1.update(arm1.set_index('id_participant'),overwrite=False)
s1.reset_index()
# Out:
#     id_participant  Unnamed: 0      redcap_event_name name_first  \
# 0        PRT170001           2  sample_a_year_1_arm_1       Amar
# 1        PRT170003           8  sample_a_year_1_arm_1       Lisa
# 2        PRT170004          12  sample_a_year_1_arm_1        Joe
# 3        PRT170007          19  sample_a_year_1_arm_1      Julie
# 4        PRT170008          24  sample_a_year_1_arm_1    Michele
# 5        PRT170009          27  sample_a_year_1_arm_1  Christine
# 6        PRT170010          32  sample_a_year_1_arm_1       Mary
# 7        PRT170011          35  sample_a_year_1_arm_1   Lizandra
# 8        PRT170014          43  sample_a_year_1_arm_1    Richard
# 9        PRT170015          48  sample_a_year_1_arm_1      Susan
# 10       PRT170016          52  sample_a_year_1_arm_1       Mary
# 11       PRT170020          61  sample_a_year_1_arm_1      JENNY
# 12       PRT170021          65  sample_a_year_1_arm_1      David
# ...

# %%
s1.head()
# Out:
#                 Unnamed: 0      redcap_event_name name_first name_middle  \
# id_participant
# PRT170001                2  sample_a_year_1_arm_1       Amar         NaN
# PRT170003                8  sample_a_year_1_arm_1       Lisa           A
# PRT170004               12  sample_a_year_1_arm_1        Joe           A
# PRT170007               19  sample_a_year_1_arm_1      Julie           A
# PRT170008               24  sample_a_year_1_arm_1    Michele           M
#
#                  name_last         dob id_primary id_secondary    id_imsms  \
# id_participant
# PRT170001       Shiwlochan  1993-01-14  PRT170001          NaN         NaN
# PRT170003       Stuczynski  1966-10-02  PRT170003          NaN         NaN
# PRT170004            Citro  1958-09-06  PRT170004          NaN         NaN
# PRT170007           Higdon  1972-07-03  PRT170007          NaN  76501-0002
# PRT170008            Brown  1962-07-20  PRT170008          NaN  76501-0016
#
# ...

# %%
s1.to_csv("sample_a_year_1_arm_1.csv")

# %%
say2 = pd.read_csv("sample_a_year_2_arm_1.csv")

# %%
say2.shape
# Out:
# (73, 444)

# %%
#list(s1)

# %%
temp2 = say2.dropna(axis=1)

# %%
temp2.shape
# Out:
# (73, 8)

# %%
temp2.describe()
# Out:
#         Unnamed: 0  blood_sample_complete  stool_sample_complete  \
# count    73.000000              73.000000              73.000000
# mean    473.753425               1.780822               0.383562
# std     341.525816               0.629077               0.792852
# min       9.000000               0.000000               0.000000
# 25%     218.000000               2.000000               0.000000
# 50%     374.000000               2.000000               0.000000
# 75%     716.000000               2.000000               0.000000
# max    1325.000000               2.000000               2.000000
#
#        urine_sample_complete  saliva_sample_complete  t_mri_complete
# count                   73.0                    73.0            73.0
# mean                     0.0                     0.0             0.0
# std                      0.0                     0.0             0.0
# min                      0.0                     0.0             0.0
# ...

# %%
say2.set_index('id_participant', inplace=True)
say2.update(arm1.set_index('id_participant'),overwrite=False)
say2.reset_index()
# Out:
#    id_participant  Unnamed: 0      redcap_event_name  name_first name_middle  \
# 0       PRT170003           9  sample_a_year_2_arm_1        Lisa           A
# 1       PRT170007          21  sample_a_year_2_arm_1       Julie           A
# 2       PRT170009          29  sample_a_year_2_arm_1   Christine           S
# 3       PRT170014          45  sample_a_year_2_arm_1     Richard           S
# 4       PRT170021          67  sample_a_year_2_arm_1       David           R
# 5       PRT170022          73  sample_a_year_2_arm_1      Sharon         NaN
# 6       PRT170023          79  sample_a_year_2_arm_1     CELESTE         NaN
# 7       PRT170024          84  sample_a_year_2_arm_1       LINDA           R
# 8       PRT170025          88  sample_a_year_2_arm_1       DEBRA         NaN
# 9       PRT170029         102  sample_a_year_2_arm_1       KATHY           K
# 10      PRT170030         107  sample_a_year_2_arm_1        LISA           K
# ...

# %%
say2.to_csv('sample_a_year_2_arm_1.csv')

# %%
sby1 = pd.read_csv("sample_b_year_1_arm_1.csv")

# %%
temp3 = sby1.dropna(axis=1)

# %%
temp2.describe()
# Out:
#         Unnamed: 0  blood_sample_complete  stool_sample_complete  \
# count    73.000000              73.000000              73.000000
# mean    473.753425               1.780822               0.383562
# std     341.525816               0.629077               0.792852
# min       9.000000               0.000000               0.000000
# 25%     218.000000               2.000000               0.000000
# 50%     374.000000               2.000000               0.000000
# 75%     716.000000               2.000000               0.000000
# max    1325.000000               2.000000               2.000000
#
#        urine_sample_complete  saliva_sample_complete  t_mri_complete
# count                   73.0                    73.0            73.0
# mean                     0.0                     0.0             0.0
# std                      0.0                     0.0             0.0
# min                      0.0                     0.0             0.0
# ...

# %%
sby1.set_index('id_participant', inplace=True)
sby1.update(arm1.set_index('id_participant'),overwrite=False)
sby1.reset_index()
# Out:
#     id_participant  Unnamed: 0      redcap_event_name name_first name_middle  \
# 0        PRT170001           3  sample_b_year_1_arm_1       Amar         NaN
# 1        PRT170007          20  sample_b_year_1_arm_1      Julie           A
# 2        PRT170009          28  sample_b_year_1_arm_1  Christine           S
# 3        PRT170011          36  sample_b_year_1_arm_1   Lizandra           S
# 4        PRT170014          44  sample_b_year_1_arm_1    Richard           S
# 5        PRT170015          49  sample_b_year_1_arm_1      Susan           M
# 6        PRT170016          53  sample_b_year_1_arm_1       Mary           L
# 7        PRT170020          62  sample_b_year_1_arm_1      JENNY         NaN
# 8        PRT170021          66  sample_b_year_1_arm_1      David           R
# 9        PRT170022          72  sample_b_year_1_arm_1     Sharon         NaN
# 10       PRT170023          77  sample_b_year_1_arm_1    CELESTE         NaN
# ...

# %%
sby1.to_csv('sample_b_year_1_arm_1.csv')

# %%
scy1 = pd.read_csv("sample_c_year_1_arm_1.csv")
temp4 = scy1.dropna(axis=1)
temp4.describe()
# Out:
#        Unnamed: 0  blood1_dmt  blood1_dmt_detail  blood1_dna  \
# count    2.000000         2.0           2.000000         2.0
# mean   482.500000         1.0           7.000000         1.0
# std    572.049386         0.0           4.242641         0.0
# min     78.000000         1.0           4.000000         1.0
# 25%    280.250000         1.0           5.500000         1.0
# 50%    482.500000         1.0           7.000000         1.0
# 75%    684.750000         1.0           8.500000         1.0
# max    887.000000         1.0          10.000000         1.0
#
#        blood_sample_complete  stool_sample_complete  t_mri_complete
# count                    2.0               2.000000             2.0
# mean                     2.0               1.000000             0.0
# std                      0.0               1.414214             0.0
# min                      2.0               0.000000             0.0
# 25%                      2.0               0.500000             0.0
# ...

# %%
scy1.set_index('id_participant', inplace=True)
scy1.update(arm1.set_index('id_participant'),overwrite=False)
scy1.reset_index()
# Out:
#   id_participant  Unnamed: 0      redcap_event_name name_first name_middle  \
# 0      PRT170023          78  sample_c_year_1_arm_1    CELESTE         NaN
# 1      PRT170333         887  sample_c_year_1_arm_1       JOAN         NaN
#
#          name_last         dob id_primary        id_secondary id_imsms  \
# 0  FLAHERTY-THOMAS  1976-03-29  PRT170023  REDCAP RECORD ID 2      NaN
# 1         ODONNELL  1963-09-16  PRT170333                 NaN      NaN
#
#             ...           mri_date_mail_sent  mri_date_signed_consent  \
# 0           ...                          NaN                      NaN
# 1           ...                          NaN                      NaN
#
#    mri_version_consent_form mri_version_date_consent_form  mri_consent_pdf  \
# 0                       NaN                           NaN              NaN
# 1                       NaN                           NaN              NaN
#
#   t_mri_complete  tdate_order  tdate_completion  notes_3t  \
# ...

# %%
scy1.to_csv('sample_c_year_1_arm_1.csv')

# %%
sdy1 = pd.read_csv("sample_d_year_1_arm_1.csv")
temp5 = sdy1.dropna(axis=1)
temp5.describe()
# Out:
#        Unnamed: 0  blood_sample_complete  stool_eligibile  \
# count         1.0                    1.0              1.0
# mean        888.0                    0.0              3.0
# std           NaN                    NaN              NaN
# min         888.0                    0.0              3.0
# 25%         888.0                    0.0              3.0
# 50%         888.0                    0.0              3.0
# 75%         888.0                    0.0              3.0
# max         888.0                    0.0              3.0
#
#        stool_sample_complete  t_mri_complete
# count                    1.0             1.0
# mean                     2.0             0.0
# std                      NaN             NaN
# min                      2.0             0.0
# 25%                      2.0             0.0
# 50%                      2.0             0.0
# 75%                      2.0             0.0
# max                      2.0             0.0

# %%
sdy1.set_index('id_participant', inplace=True)
sdy1.update(arm1.set_index('id_participant'),overwrite=False)
sdy1.reset_index()
# Out:
#   id_participant  Unnamed: 0      redcap_event_name name_first name_middle  \
# 0      PRT170333         888  sample_d_year_1_arm_1       JOAN         NaN
#
#   name_last         dob id_primary id_secondary id_imsms  \
# 0  ODONNELL  1963-09-16  PRT170333          NaN      NaN
#
#             ...           mri_date_mail_sent  mri_date_signed_consent  \
# 0           ...                          NaN                      NaN
#
#    mri_version_consent_form mri_version_date_consent_form  mri_consent_pdf  \
# 0                       NaN                           NaN              NaN
#
#   t_mri_complete  tdate_order  tdate_completion  notes_3t  \
# 0            0.0   2018-08-21        2018-09-08       NaN
#
#    subtle_3t_mri_complete
# 0                     2.0
#
# [1 rows x 444 columns]

# %%
sdy1.to_csv('sample_d_year_1_arm_1.csv')

# %%
y1 = pd.read_csv("year_1_arm_1.csv")
temp6 = y1.dropna(axis=1)
temp6.describe()
# Out:
#         Unnamed: 0  csf_sample_complete  dna_sample_complete  \
# count   452.000000           452.000000                452.0
# mean    896.692478             0.053097                  0.0
# std     518.658803             0.321877                  0.0
# min       1.000000             0.000000                  0.0
# 25%     457.500000             0.000000                  0.0
# 50%     910.000000             0.000000                  0.0
# 75%    1338.500000             0.000000                  0.0
# max    1862.000000             2.000000                  0.0
#
#        tug_observation___0  tug_observation___1  tug_observation___2  \
# count                452.0                452.0                452.0
# mean                   0.0                  0.0                  0.0
# std                    0.0                  0.0                  0.0
# min                    0.0                  0.0                  0.0
# ...

# %%
y1.isnull().sum()
# Out:
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       452
# name_middle                      452
# name_last                        452
# dob                              452
# id_primary                       452
# id_secondary                     452
# id_imsms                         452
# id_med_record_number             452
# subject_group                    452
# recruitment_source               452
# recruitment_source_other         452
# enrollment_site                  452
# other_enrollment                 452
# msdx_recruitment                 452
# msdx_current                     452
# medical_release                  452
# msdx_validated                   452
# msdx_validated_upload            452
# date_firstsx                     452
# age_firstsx                      452
# type_firstsx                     452
# date_msdx                        452
# ...

# %%
temp6.shape
# Out:
# (452, 18)

# %%
y1.set_index('id_participant', inplace=True)
y1.update(arm1.set_index('id_participant'),overwrite=False)
y1.reset_index()
# Out:
#     id_participant  Unnamed: 0 redcap_event_name name_first  \
# 0        PRT170001           1      year_1_arm_1       Amar
# 1        PRT170002           5      year_1_arm_1  Catherine
# 2        PRT170003           7      year_1_arm_1       Lisa
# 3        PRT170004          11      year_1_arm_1        Joe
# 4        PRT170005          14      year_1_arm_1      Harry
# 5        PRT170006          16      year_1_arm_1    Richard
# 6        PRT170007          18      year_1_arm_1      Julie
# 7        PRT170008          23      year_1_arm_1    Michele
# 8        PRT170009          26      year_1_arm_1  Christine
# 9        PRT170010          31      year_1_arm_1       Mary
# 10       PRT170011          34      year_1_arm_1   Lizandra
# 11       PRT170012          38      year_1_arm_1    William
# 12       PRT170013          40      year_1_arm_1       Brad
# 13       PRT170014          42      year_1_arm_1    Richard
# 14       PRT170015          47      year_1_arm_1      Susan
# ...

# %%
y1.to_csv('year_1_arm_1.csv')

# %%
sby2 = pd.read_csv("sample_b_year_2_arm_1.csv")
temp7 = sby2.dropna(axis = 1)
temp7.shape
# Out:
# (12, 9)

# %%
temp7.describe()
# Out:
#        Unnamed: 0  blood_sample_complete  stool_eligibile  \
# count   12.000000              12.000000        12.000000
# mean   358.250000               0.166667         2.833333
# std    236.217206               0.577350         0.577350
# min     68.000000               0.000000         1.000000
# 25%    191.250000               0.000000         3.000000
# 50%    302.000000               0.000000         3.000000
# 75%    542.750000               0.000000         3.000000
# max    717.000000               2.000000         3.000000
#
#        stool_sample_complete  urine_sample_complete  saliva_sample_complete  \
# count              12.000000                   12.0                    12.0
# mean                1.666667                    0.0                     0.0
# std                 0.778499                    0.0                     0.0
# min                 0.000000                    0.0                     0.0
# ...

# %%
sby2.set_index('id_participant', inplace=True)
sby2.update(arm1.set_index('id_participant'),overwrite=False)
sby2.reset_index()
# Out:
#    id_participant  Unnamed: 0      redcap_event_name name_first name_middle  \
# 0       PRT170021          68  sample_b_year_2_arm_1      David           R
# 1       PRT170024          85  sample_b_year_2_arm_1      LINDA           R
# 2       PRT170030         108  sample_b_year_2_arm_1       LISA           K
# 3       PRT170072         219  sample_b_year_2_arm_1       Lois           M
# 4       PRT170073         224  sample_b_year_2_arm_1      TAMMY           L
# 5       prt170082         256  sample_b_year_2_arm_1     Maliha         NaN
# 6       PRT170110         348  sample_b_year_2_arm_1    Kenneth         NaN
# 7       PRT170144         439  sample_b_year_2_arm_1      Merri           I
# 8       PRT170175         516  sample_b_year_2_arm_1   Kathleen         NaN
# 9       PRT170221         623  sample_b_year_2_arm_1   Terrance         NaN
# 10      PRT170251         696  sample_b_year_2_arm_1    JOCELYN           R
# ...

# %%
sby2.to_csv('sample_b_year_2_arm_1.csv')

# %%
arm2_files = [x for x in list_events if 'arm_2' in x]
arm2_files
# Out:
# ['consent_initial_vi_arm_2', 'year_1a_arm_2', 'year_2_arm_2']

# %%
arm2 = pd.read_csv("consent_initial_vi_arm_2.csv")

# %%
arm2.shape
# Out:
# (72, 444)

# %%
arm2.isnull().sum()
# Out:
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                        0
# name_middle                      65
# name_last                         0
# dob                              48
# id_primary                        1
# id_secondary                     70
# id_imsms                         43
# id_med_record_number             66
# subject_group                     0
# recruitment_source               29
# recruitment_source_other         63
# enrollment_site                  10
# other_enrollment                 54
# msdx_recruitment                 19
# msdx_current                     24
# medical_release                  55
# msdx_validated                   57
# msdx_validated_upload            72
# date_firstsx                     71
# age_firstsx                      71
# type_firstsx                     71
# date_msdx                        72
# method_msdx___1                   0
# ...

# %%
arm2.describe()
# Out:
#         Unnamed: 0  id_med_record_number  subject_group  recruitment_source  \
# count    72.000000          6.000000e+00      72.000000           43.000000
# mean   1267.500000          7.909471e+08       2.972222           30.511628
# std     543.881045          5.652674e+07       0.235702           31.096143
# min     182.000000          7.377603e+08       1.000000           12.000000
# 25%     833.500000          7.401163e+08       3.000000           12.000000
# 50%    1443.000000          7.908312e+08       3.000000           18.000000
# 75%    1754.750000          8.426059e+08       3.000000           19.000000
# max    1928.000000          8.431845e+08       3.000000           90.000000
#
#        enrollment_site  msdx_recruitment  msdx_current  medical_release  \
# count        62.000000         53.000000     48.000000             17.0
# mean          1.451613          0.018868      0.020833              0.0
# ...

# %%
y1a2 = pd.read_csv("year_1a_arm_2.csv")

# %%
temp8 = arm2.dropna(axis=1)
temp8.shape
# Out:
# (72, 57)

# %%
temp9 = y1a2.dropna(axis=1)
temp9.shape
# Out:
# (30, 7)

# %%
temp9.describe()
# Out:
#         Unnamed: 0  blood_sample_complete  stool_sample_complete  \
# count    30.000000              30.000000              30.000000
# mean   1245.766667               0.733333               1.266667
# std     534.887399               0.980265               0.980265
# min     183.000000               0.000000               0.000000
# 25%     817.000000               0.000000               0.000000
# 50%    1468.000000               0.000000               2.000000
# 75%    1649.750000               2.000000               2.000000
# max    1867.000000               2.000000               2.000000
#
#        urine_sample_complete  saliva_sample_complete
# count                   30.0                    30.0
# mean                     0.0                     0.0
# std                      0.0                     0.0
# min                      0.0                     0.0
# 25%                      0.0                     0.0
# 50%                      0.0                     0.0
# ...

# %%
y2a2 = pd.read_csv("year_2_arm_2.csv")

# %%
temp10 = y2a2.dropna(axis=1)
temp10.shape
# Out:
# (4, 23)

# %%
temp10.describe()
# Out:
#         Unnamed: 0  primary_questionnaire_complete  \
# count     4.000000                             4.0
# mean   1077.750000                             0.0
# std     543.723199                             0.0
# min     534.000000                             0.0
# 25%     657.000000                             0.0
# 50%    1068.000000                             0.0
# 75%    1488.750000                             0.0
# max    1641.000000                             0.0
#
#        self_reported_outcome_questionnaire_complete  blood_sample_complete  \
# count                                           4.0                    4.0
# mean                                            0.0                    0.5
# std                                             0.0                    1.0
# min                                             0.0                    0.0
# 25%                                             0.0                    0.0
# ...

# %%
y1a2.set_index('id_participant', inplace=True)
y1a2.update(arm2.set_index('id_participant'),overwrite=False)
y1a2.reset_index()
# Out:
#    id_participant  Unnamed: 0 redcap_event_name   name_first name_middle  \
# 0       PRT170056         183     year_1a_arm_2       Emily          NaN
# 1       PRT170087         272     year_1a_arm_2        Wayne         NaN
# 2       PRT170116         361     year_1a_arm_2    Cassandra         NaN
# 3       PRT170147         446     year_1a_arm_2         Brad         NaN
# 4       PRT170149         449     year_1a_arm_2       Daniel         NaN
# 5       PRT170198         569     year_1a_arm_2         JOHN         NaN
# 6       PRT170200         573     year_1a_arm_2         John         NaN
# 7       PRT170276         758     year_1a_arm_2          Joe         NaN
# 8       PRT170380         994     year_1a_arm_2       EDWARD         NaN
# 9       PRT170388        1013     year_1a_arm_2  JOHN (JACK)         NaN
# 10      PRT170512        1257     year_1a_arm_2      BERNARD           J
# 11      PRT170539        1314     year_1a_arm_2         KENT         NaN
# ...

# %%
y1a2.to_csv('year_1a_arm_2.csv')

# %%
y2a2.set_index('id_participant', inplace=True)
y2a2.update(arm2.set_index('id_participant'),overwrite=False)
y2a2.reset_index()
# Out:
#   id_participant  Unnamed: 0 redcap_event_name name_first name_middle  \
# 0      PRT170184         534      year_2_arm_2      GREGG         NaN
# 1      PRT170252         698      year_2_arm_2    Deborah         NaN
# 2      PRT180596        1438      year_2_arm_2       RICH         NaN
# 3      PRT180698        1641      year_2_arm_2    Roberta         NaN
#
#   name_last         dob id_primary id_secondary    id_imsms  \
# 0   BROUJOS         NaN  PRT170184          NaN  76502-0048
# 1   Steiner         NaN  PRT170252          NaN         NaN
# 2   CREEHAN         NaN  PRT180596          NaN  76502-0038
# 3   Treloar  1960-02-03  PRT180698          NaN  76502-0045
#
#             ...            mri_date_mail_sent  mri_date_signed_consent  \
# 0           ...                           NaN                      NaN
# 1           ...                           NaN                      NaN
# 2           ...                           NaN                      NaN
# ...

# %%
y2a2.to_csv('year_2_arm_2.csv')

# %%
y2a2.head()
# Out:
#                 Unnamed: 0 redcap_event_name name_first name_middle name_last  \
# id_participant
# PRT170184              534      year_2_arm_2      GREGG         NaN   BROUJOS
# PRT170252              698      year_2_arm_2    Deborah         NaN   Steiner
# PRT180596             1438      year_2_arm_2       RICH         NaN   CREEHAN
# PRT180698             1641      year_2_arm_2    Roberta         NaN   Treloar
#
#                        dob id_primary id_secondary    id_imsms  \
# id_participant
# PRT170184              NaN  PRT170184          NaN  76502-0048
# PRT170252              NaN  PRT170252          NaN         NaN
# PRT180596              NaN  PRT180596          NaN  76502-0038
# PRT180698       1960-02-03  PRT180698          NaN  76502-0045
#
#                 id_med_record_number           ...            \
# id_participant                                 ...
# PRT170184                        NaN           ...
# PRT170252                        NaN           ...
# ...
