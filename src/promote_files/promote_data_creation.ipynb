# %%
import numpy as np
import pandas as pd

# %%
input_pre = 'csv_files/input_files/'
output_pre = 'csv_files/output_files/' 
main = pd.read_csv(input_pre + 'main.csv')
print(main.shape)
# Out:
# (1935, 443)

# %%
group_data = main.groupby('redcap_event_name')[['id_participant']].count()
group_data
# Out:
#                           id_participant
# redcap_event_name
# consent_initial_vi_arm_1             835
# consent_initial_vi_arm_2              73
# sample_a_year_1_arm_1                304
# sample_a_year_2_arm_1                 73
# sample_b_year_1_arm_1                149
# sample_b_year_2_arm_1                 12
# sample_c_year_1_arm_1                  2
# sample_d_year_1_arm_1                  1
# year_1_arm_1                         452
# year_1a_arm_2                         30
# year_2_arm_2                           4

# %%
list_events = main['redcap_event_name'].unique()
list_events
# Out:
# array(['consent_initial_vi_arm_1', 'year_1_arm_1',
#        'sample_a_year_1_arm_1', 'sample_b_year_1_arm_1',
#        'sample_a_year_2_arm_1', 'sample_b_year_2_arm_1',
#        'sample_c_year_1_arm_1', 'consent_initial_vi_arm_2',
#        'year_1a_arm_2', 'year_2_arm_2', 'sample_d_year_1_arm_1'],
#       dtype=object)

# %%
for event in list_events:
    data = main[main['redcap_event_name'] == event]
    data.to_csv(output_pre + event + ".csv")
    
consent_files = [x for x in list_events if 'consent_initial' in x]

for f in consent_files:
    arm = pd.read_csv(output_pre + f + ".csv")
    arm_type = f.split('vi_')[-1]
    arm_files = [x for x in list_events if arm_type in x]
    for subfile in arm_files:
        sub =  pd.read_csv(output_pre + subfile + ".csv")
        print(sub.shape)
        print(sub.isnull().sum())
        sub.set_index('id_participant', inplace=True)
        sub.update(arm.set_index('id_participant'),overwrite=False)
        sub.reset_index()
        sub.to_csv(output_pre + subfile+ ".csv")
# Out:
# (835, 444)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                         1
# name_middle                      355
# name_last                          1
# dob                                4
# id_primary                         4
# id_secondary                     794
# id_imsms                         789
# id_med_record_number              31
# subject_group                     10
# recruitment_source                 3
# recruitment_source_other         726
# enrollment_site                    5
# other_enrollment                 772
# msdx_recruitment                  19
# msdx_current                      25
# medical_release                  785
# msdx_validated                   107
# msdx_validated_upload            826
# date_firstsx                     161
# age_firstsx                      179
# type_firstsx                     250
# date_msdx                         96
# method_msdx___1                    0
# method_msdx___2                    0
# method_msdx___3                    0
# method_msdx___4                    0
# msdx_documentation               832
#                                 ...
# dmt_sixth_end                    833
# dmt_seventh                      833
# dmt_seventh_start                833
# dmt_seventh_end                  834
# dmt_eighth                       834
# dmt_eighth_start                 834
# dmt_eighth_end                   835
# dmt_ninth                        835
# dmt_ninth_start                  835
# dmt_ninth_end                    835
# dmt_tenth                        835
# dmt_tenth_start                  835
# dmt_tenth_end                    835
# dmt_history_complete               0
# mri_screening_complete           835
# mri_screening_eligible           835
# mri_scan_research                835
# mri_scan_clinical                835
# mri_consent_how                  835
# mri_date_electronic_sent         835
# mri_date_mail_sent               835
# mri_date_signed_consent          835
# mri_version_consent_form         835
# mri_version_date_consent_form    835
# mri_consent_pdf                  835
# t_mri_complete                   835
# tdate_order                      787
# tdate_completion                 803
# notes_3t                         835
# subtle_3t_mri_complete             0
# Length: 444, dtype: int64
# (452, 444)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       452
# name_middle                      452
# name_last                        452
# dob                              452
# id_primary                       452
# id_secondary                     452
# id_imsms                         452
# id_med_record_number             452
# subject_group                    452
# recruitment_source               452
# recruitment_source_other         452
# enrollment_site                  452
# other_enrollment                 452
# msdx_recruitment                 452
# msdx_current                     452
# medical_release                  452
# msdx_validated                   452
# msdx_validated_upload            452
# date_firstsx                     452
# age_firstsx                      452
# type_firstsx                     452
# date_msdx                        452
# method_msdx___1                  452
# method_msdx___2                  452
# method_msdx___3                  452
# method_msdx___4                  452
# msdx_documentation               452
#                                 ...
# dmt_sixth_end                    452
# dmt_seventh                      452
# dmt_seventh_start                452
# dmt_seventh_end                  452
# dmt_eighth                       452
# dmt_eighth_start                 452
# dmt_eighth_end                   452
# dmt_ninth                        452
# dmt_ninth_start                  452
# dmt_ninth_end                    452
# dmt_tenth                        452
# dmt_tenth_start                  452
# dmt_tenth_end                    452
# dmt_history_complete             452
# mri_screening_complete           452
# mri_screening_eligible           452
# mri_scan_research                452
# mri_scan_clinical                452
# mri_consent_how                  452
# mri_date_electronic_sent         452
# mri_date_mail_sent               452
# mri_date_signed_consent          452
# mri_version_consent_form         452
# mri_version_date_consent_form    452
# mri_consent_pdf                  452
# t_mri_complete                   452
# tdate_order                      452
# tdate_completion                 452
# notes_3t                         452
# subtle_3t_mri_complete           452
# Length: 444, dtype: int64
# (304, 444)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       304
# name_middle                      304
# name_last                        304
# dob                              304
# id_primary                       304
# id_secondary                     304
# id_imsms                         304
# id_med_record_number             304
# subject_group                    304
# recruitment_source               304
# recruitment_source_other         304
# enrollment_site                  304
# other_enrollment                 304
# msdx_recruitment                 304
# msdx_current                     304
# medical_release                  304
# msdx_validated                   304
# msdx_validated_upload            304
# date_firstsx                     304
# age_firstsx                      304
# type_firstsx                     304
# date_msdx                        304
# method_msdx___1                  304
# method_msdx___2                  304
# method_msdx___3                  304
# method_msdx___4                  304
# msdx_documentation               304
#                                 ...
# dmt_sixth_end                    304
# dmt_seventh                      304
# dmt_seventh_start                304
# dmt_seventh_end                  304
# dmt_eighth                       304
# dmt_eighth_start                 304
# dmt_eighth_end                   304
# dmt_ninth                        304
# dmt_ninth_start                  304
# dmt_ninth_end                    304
# dmt_tenth                        304
# dmt_tenth_start                  304
# dmt_tenth_end                    304
# dmt_history_complete             304
# mri_screening_complete           265
# mri_screening_eligible           266
# mri_scan_research                284
# mri_scan_clinical                290
# mri_consent_how                  259
# mri_date_electronic_sent         283
# mri_date_mail_sent               303
# mri_date_signed_consent          260
# mri_version_consent_form         259
# mri_version_date_consent_form    260
# mri_consent_pdf                  258
# t_mri_complete                     0
# tdate_order                      304
# tdate_completion                 304
# notes_3t                         304
# subtle_3t_mri_complete           304
# Length: 444, dtype: int64
# (149, 444)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       149
# name_middle                      149
# name_last                        149
# dob                              149
# id_primary                       149
# id_secondary                     149
# id_imsms                         149
# id_med_record_number             149
# subject_group                    149
# recruitment_source               149
# recruitment_source_other         149
# enrollment_site                  149
# other_enrollment                 149
# msdx_recruitment                 149
# msdx_current                     149
# medical_release                  149
# msdx_validated                   149
# msdx_validated_upload            149
# date_firstsx                     149
# age_firstsx                      149
# type_firstsx                     149
# date_msdx                        149
# method_msdx___1                  149
# method_msdx___2                  149
# method_msdx___3                  149
# method_msdx___4                  149
# msdx_documentation               149
#                                 ...
# dmt_sixth_end                    149
# dmt_seventh                      149
# dmt_seventh_start                149
# dmt_seventh_end                  149
# dmt_eighth                       149
# dmt_eighth_start                 149
# dmt_eighth_end                   149
# dmt_ninth                        149
# dmt_ninth_start                  149
# dmt_ninth_end                    149
# dmt_tenth                        149
# dmt_tenth_start                  149
# dmt_tenth_end                    149
# dmt_history_complete             149
# mri_screening_complete           149
# mri_screening_eligible           149
# mri_scan_research                149
# mri_scan_clinical                149
# mri_consent_how                  149
# mri_date_electronic_sent         149
# mri_date_mail_sent               149
# mri_date_signed_consent          149
# mri_version_consent_form         149
# mri_version_date_consent_form    149
# mri_consent_pdf                  149
# t_mri_complete                     0
# tdate_order                      149
# tdate_completion                 149
# notes_3t                         149
# subtle_3t_mri_complete           149
# Length: 444, dtype: int64
# (73, 444)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       73
# name_middle                      73
# name_last                        73
# dob                              73
# id_primary                       73
# id_secondary                     73
# id_imsms                         73
# id_med_record_number             73
# subject_group                    73
# recruitment_source               73
# recruitment_source_other         73
# enrollment_site                  73
# other_enrollment                 73
# msdx_recruitment                 73
# msdx_current                     73
# medical_release                  73
# msdx_validated                   73
# msdx_validated_upload            73
# date_firstsx                     73
# age_firstsx                      73
# type_firstsx                     73
# date_msdx                        73
# method_msdx___1                  73
# method_msdx___2                  73
# method_msdx___3                  73
# method_msdx___4                  73
# msdx_documentation               73
#                                  ..
# dmt_sixth_end                    73
# dmt_seventh                      73
# dmt_seventh_start                73
# dmt_seventh_end                  73
# dmt_eighth                       73
# dmt_eighth_start                 73
# dmt_eighth_end                   73
# dmt_ninth                        73
# dmt_ninth_start                  73
# dmt_ninth_end                    73
# dmt_tenth                        73
# dmt_tenth_start                  73
# dmt_tenth_end                    73
# dmt_history_complete             73
# mri_screening_complete           73
# mri_screening_eligible           73
# mri_scan_research                73
# mri_scan_clinical                73
# mri_consent_how                  73
# mri_date_electronic_sent         73
# mri_date_mail_sent               73
# mri_date_signed_consent          73
# mri_version_consent_form         73
# mri_version_date_consent_form    73
# mri_consent_pdf                  73
# t_mri_complete                    0
# tdate_order                      73
# tdate_completion                 73
# notes_3t                         73
# subtle_3t_mri_complete           73
# Length: 444, dtype: int64
# (12, 444)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       12
# name_middle                      12
# name_last                        12
# dob                              12
# id_primary                       12
# id_secondary                     12
# id_imsms                         12
# id_med_record_number             12
# subject_group                    12
# recruitment_source               12
# recruitment_source_other         12
# enrollment_site                  12
# other_enrollment                 12
# msdx_recruitment                 12
# msdx_current                     12
# medical_release                  12
# msdx_validated                   12
# msdx_validated_upload            12
# date_firstsx                     12
# age_firstsx                      12
# type_firstsx                     12
# date_msdx                        12
# method_msdx___1                  12
# method_msdx___2                  12
# method_msdx___3                  12
# method_msdx___4                  12
# msdx_documentation               12
#                                  ..
# dmt_sixth_end                    12
# dmt_seventh                      12
# dmt_seventh_start                12
# dmt_seventh_end                  12
# dmt_eighth                       12
# dmt_eighth_start                 12
# dmt_eighth_end                   12
# dmt_ninth                        12
# dmt_ninth_start                  12
# dmt_ninth_end                    12
# dmt_tenth                        12
# dmt_tenth_start                  12
# dmt_tenth_end                    12
# dmt_history_complete             12
# mri_screening_complete           12
# mri_screening_eligible           12
# mri_scan_research                12
# mri_scan_clinical                12
# mri_consent_how                  12
# mri_date_electronic_sent         12
# mri_date_mail_sent               12
# mri_date_signed_consent          12
# mri_version_consent_form         12
# mri_version_date_consent_form    12
# mri_consent_pdf                  12
# t_mri_complete                    0
# tdate_order                      12
# tdate_completion                 12
# notes_3t                         12
# subtle_3t_mri_complete           12
# Length: 444, dtype: int64
# (2, 444)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       2
# name_middle                      2
# name_last                        2
# dob                              2
# id_primary                       2
# id_secondary                     2
# id_imsms                         2
# id_med_record_number             2
# subject_group                    2
# recruitment_source               2
# recruitment_source_other         2
# enrollment_site                  2
# other_enrollment                 2
# msdx_recruitment                 2
# msdx_current                     2
# medical_release                  2
# msdx_validated                   2
# msdx_validated_upload            2
# date_firstsx                     2
# age_firstsx                      2
# type_firstsx                     2
# date_msdx                        2
# method_msdx___1                  2
# method_msdx___2                  2
# method_msdx___3                  2
# method_msdx___4                  2
# msdx_documentation               2
#                                 ..
# dmt_sixth_end                    2
# dmt_seventh                      2
# dmt_seventh_start                2
# dmt_seventh_end                  2
# dmt_eighth                       2
# dmt_eighth_start                 2
# dmt_eighth_end                   2
# dmt_ninth                        2
# dmt_ninth_start                  2
# dmt_ninth_end                    2
# dmt_tenth                        2
# dmt_tenth_start                  2
# dmt_tenth_end                    2
# dmt_history_complete             2
# mri_screening_complete           2
# mri_screening_eligible           2
# mri_scan_research                2
# mri_scan_clinical                2
# mri_consent_how                  2
# mri_date_electronic_sent         2
# mri_date_mail_sent               2
# mri_date_signed_consent          2
# mri_version_consent_form         2
# mri_version_date_consent_form    2
# mri_consent_pdf                  2
# t_mri_complete                   0
# tdate_order                      2
# tdate_completion                 2
# notes_3t                         2
# subtle_3t_mri_complete           2
# Length: 444, dtype: int64
# (1, 444)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       1
# name_middle                      1
# name_last                        1
# dob                              1
# id_primary                       1
# id_secondary                     1
# id_imsms                         1
# id_med_record_number             1
# subject_group                    1
# recruitment_source               1
# recruitment_source_other         1
# enrollment_site                  1
# other_enrollment                 1
# msdx_recruitment                 1
# msdx_current                     1
# medical_release                  1
# msdx_validated                   1
# msdx_validated_upload            1
# date_firstsx                     1
# age_firstsx                      1
# type_firstsx                     1
# date_msdx                        1
# method_msdx___1                  1
# method_msdx___2                  1
# method_msdx___3                  1
# method_msdx___4                  1
# msdx_documentation               1
#                                 ..
# dmt_sixth_end                    1
# dmt_seventh                      1
# dmt_seventh_start                1
# dmt_seventh_end                  1
# dmt_eighth                       1
# dmt_eighth_start                 1
# dmt_eighth_end                   1
# dmt_ninth                        1
# dmt_ninth_start                  1
# dmt_ninth_end                    1
# dmt_tenth                        1
# dmt_tenth_start                  1
# dmt_tenth_end                    1
# dmt_history_complete             1
# mri_screening_complete           1
# mri_screening_eligible           1
# mri_scan_research                1
# mri_scan_clinical                1
# mri_consent_how                  1
# mri_date_electronic_sent         1
# mri_date_mail_sent               1
# mri_date_signed_consent          1
# mri_version_consent_form         1
# mri_version_date_consent_form    1
# mri_consent_pdf                  1
# t_mri_complete                   0
# tdate_order                      1
# tdate_completion                 1
# notes_3t                         1
# subtle_3t_mri_complete           1
# Length: 444, dtype: int64
# (73, 444)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                        0
# name_middle                      66
# name_last                         0
# dob                              49
# id_primary                        1
# id_secondary                     71
# id_imsms                         44
# id_med_record_number             67
# subject_group                     0
# recruitment_source               29
# recruitment_source_other         64
# enrollment_site                  10
# other_enrollment                 55
# msdx_recruitment                 19
# msdx_current                     25
# medical_release                  56
# msdx_validated                   58
# msdx_validated_upload            73
# date_firstsx                     72
# age_firstsx                      72
# type_firstsx                     72
# date_msdx                        73
# method_msdx___1                   0
# method_msdx___2                   0
# method_msdx___3                   0
# method_msdx___4                   0
# msdx_documentation               73
#                                  ..
# dmt_sixth_end                    73
# dmt_seventh                      73
# dmt_seventh_start                73
# dmt_seventh_end                  73
# dmt_eighth                       73
# dmt_eighth_start                 73
# dmt_eighth_end                   73
# dmt_ninth                        73
# dmt_ninth_start                  73
# dmt_ninth_end                    73
# dmt_tenth                        73
# dmt_tenth_start                  73
# dmt_tenth_end                    73
# dmt_history_complete             73
# mri_screening_complete           72
# mri_screening_eligible           71
# mri_scan_research                73
# mri_scan_clinical                73
# mri_consent_how                  71
# mri_date_electronic_sent         73
# mri_date_mail_sent               73
# mri_date_signed_consent          72
# mri_version_consent_form         71
# mri_version_date_consent_form    71
# mri_consent_pdf                  71
# t_mri_complete                    0
# tdate_order                      73
# tdate_completion                 73
# notes_3t                         73
# subtle_3t_mri_complete           73
# Length: 444, dtype: int64
# (30, 444)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       30
# name_middle                      30
# name_last                        30
# dob                              30
# id_primary                       30
# id_secondary                     30
# id_imsms                         30
# id_med_record_number             30
# subject_group                    30
# recruitment_source               30
# recruitment_source_other         30
# enrollment_site                  30
# other_enrollment                 30
# msdx_recruitment                 30
# msdx_current                     30
# medical_release                  30
# msdx_validated                   30
# msdx_validated_upload            30
# date_firstsx                     30
# age_firstsx                      30
# type_firstsx                     30
# date_msdx                        30
# method_msdx___1                  30
# method_msdx___2                  30
# method_msdx___3                  30
# method_msdx___4                  30
# msdx_documentation               30
#                                  ..
# dmt_sixth_end                    30
# dmt_seventh                      30
# dmt_seventh_start                30
# dmt_seventh_end                  30
# dmt_eighth                       30
# dmt_eighth_start                 30
# dmt_eighth_end                   30
# dmt_ninth                        30
# dmt_ninth_start                  30
# dmt_ninth_end                    30
# dmt_tenth                        30
# dmt_tenth_start                  30
# dmt_tenth_end                    30
# dmt_history_complete             30
# mri_screening_complete           30
# mri_screening_eligible           30
# mri_scan_research                30
# mri_scan_clinical                30
# mri_consent_how                  30
# mri_date_electronic_sent         30
# mri_date_mail_sent               30
# mri_date_signed_consent          30
# mri_version_consent_form         30
# mri_version_date_consent_form    30
# mri_consent_pdf                  30
# t_mri_complete                   30
# tdate_order                      30
# tdate_completion                 30
# notes_3t                         30
# subtle_3t_mri_complete           30
# Length: 444, dtype: int64
# (4, 444)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       4
# name_middle                      4
# name_last                        4
# dob                              4
# id_primary                       4
# id_secondary                     4
# id_imsms                         4
# id_med_record_number             4
# subject_group                    4
# recruitment_source               4
# recruitment_source_other         4
# enrollment_site                  4
# other_enrollment                 4
# msdx_recruitment                 4
# msdx_current                     4
# medical_release                  4
# msdx_validated                   4
# msdx_validated_upload            4
# date_firstsx                     4
# age_firstsx                      4
# type_firstsx                     4
# date_msdx                        4
# method_msdx___1                  4
# method_msdx___2                  4
# method_msdx___3                  4
# method_msdx___4                  4
# msdx_documentation               4
#                                 ..
# dmt_sixth_end                    4
# dmt_seventh                      4
# dmt_seventh_start                4
# dmt_seventh_end                  4
# dmt_eighth                       4
# dmt_eighth_start                 4
# dmt_eighth_end                   4
# dmt_ninth                        4
# dmt_ninth_start                  4
# dmt_ninth_end                    4
# dmt_tenth                        4
# dmt_tenth_start                  4
# dmt_tenth_end                    4
# dmt_history_complete             4
# mri_screening_complete           4
# mri_screening_eligible           4
# mri_scan_research                4
# mri_scan_clinical                4
# mri_consent_how                  4
# mri_date_electronic_sent         4
# mri_date_mail_sent               4
# mri_date_signed_consent          4
# mri_version_consent_form         4
# mri_version_date_consent_form    4
# mri_consent_pdf                  4
# t_mri_complete                   4
# tdate_order                      4
# tdate_completion                 4
# notes_3t                         4
# subtle_3t_mri_complete           4
# Length: 444, dtype: int64

# %% [markdown]
# ### Merging

# %%
mainfile = pd.read_csv(output_pre + list_events[0] + '.csv')
other_files = list_events[1:]
for file in other_files:
    subfile = pd.read_csv(output_pre + file + ".csv")
    mainfile = pd.concat([mainfile, subfile],sort=False)

# %%
mainfile.shape
# Out:
# (1935, 444)

# %%
mainfile.to_csv(output_pre + "promote_database.csv")
