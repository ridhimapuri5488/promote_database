# %%
import pycurl
import io
from urllib.parse import urlencode
import pandas as pd

data = {
    'token': '89DCF6943B10616B328CA2C3AE068CF0',
    'content': 'record',
    'format': 'csv',
    'type': 'flat',
    'rawOrLabel': 'raw',
    'rawOrLabelHeaders': 'raw',
    'exportCheckboxLabel': 'false',
    'exportSurveyFields': 'false',
    'exportDataAccessGroups': 'false',
    'returnFormat': 'json'
}

buf = io.BytesIO()
ch = pycurl.Curl()
ch.setopt(ch.URL, "https://www.ctsiredcap.pitt.edu/redcap/api/")

postfields = urlencode(data)
ch.setopt(ch.POSTFIELDS, postfields)
#ch.setopt(ch.POST, data.items())

ch.setopt(ch.WRITEFUNCTION, buf.write)
ch.perform()
ch.close()


body = buf.getvalue()
#print(body)

# %%
type(body)
# Out:
# bytes

# %%
from io import StringIO

s=str(body,'utf-8')
data = StringIO(s) 
main = pd.read_csv(data)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10,15,31,59,87,88,101,109,118,120,122,149,188,189,202,205,214,216,218,231,262,271,272,273,277,299,300,314,338,428,429,430,439,441,443,445,447,449,451,460,462,463,465,466,468,469,471,472,474,475,477,491,492,498,499) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
main.head(10)
# Out:
#   id_participant         redcap_event_name name_first name_middle   name_last  \
# 0              1  consent_initial_vi_arm_1        NaN         NaN         NaN
# 1      PRT170001  consent_initial_vi_arm_1       Amar         NaN  Shiwlochan
# 2      PRT170001              year_1_arm_1        NaN         NaN         NaN
# 3      PRT170001     sample_a_year_1_arm_1        NaN         NaN         NaN
# 4      PRT170001     sample_b_year_1_arm_1        NaN         NaN         NaN
# 5      PRT170002  consent_initial_vi_arm_1  Catherine           V      Liadis
# 6      PRT170002              year_1_arm_1        NaN         NaN         NaN
# 7      PRT170003  consent_initial_vi_arm_1       Lisa           A  Stuczynski
# 8      PRT170003              year_1_arm_1        NaN         NaN         NaN
# 9      PRT170003     sample_a_year_1_arm_1        NaN         NaN         NaN
#
#           dob  subject_sex  race  ethnicity id_primary  ...  \
# 0         NaN          NaN   NaN        NaN        NaN  ...
# 1  1993-01-14          1.0   3.0        2.0  PRT170001  ...
# 2         NaN          NaN   NaN        NaN        NaN  ...
# 3         NaN          NaN   NaN        NaN        NaN  ...
# 4         NaN          NaN   NaN        NaN        NaN  ...
# 5  1950-02-23          2.0   4.0        2.0  PRT170002  ...
# 6         NaN          NaN   NaN        NaN        NaN  ...
# 7  1966-10-02          2.0   4.0        2.0  PRT170003  ...
# 8         NaN          NaN   NaN        NaN        NaN  ...
# 9         NaN          NaN   NaN        NaN        NaN  ...
#
#   mri_date_mail_sent mri_date_signed_consent  mri_version_consent_form  \
# 0                NaN                     NaN                       NaN
# 1                NaN                     NaN                       NaN
# 2                NaN                     NaN                       NaN
# 3                NaN                     NaN                       NaN
# 4                NaN                     NaN                       NaN
# 5                NaN                     NaN                       NaN
# 6                NaN                     NaN                       NaN
# 7                NaN                     NaN                       NaN
# 8                NaN                     NaN                       NaN
# 9                NaN                     NaN                       NaN
#
#    mri_version_date_consent_form  mri_consent_pdf t_mri_complete  tdate_order  \
# 0                            NaN              NaN            NaN          NaN
# 1                            NaN              NaN            NaN          NaN
# 2                            NaN              NaN            NaN          NaN
# 3                            NaN              NaN            0.0          NaN
# 4                            NaN              NaN            0.0          NaN
# 5                            NaN              NaN            NaN          NaN
# 6                            NaN              NaN            NaN          NaN
# 7                            NaN              NaN            NaN          NaN
# 8                            NaN              NaN            NaN          NaN
# 9                            NaN              NaN            0.0          NaN
#
#   tdate_completion  notes_3t  subtle_3t_mri_complete
# 0              NaN       NaN                     0.0
# 1              NaN       NaN                     0.0
# 2              NaN       NaN                     NaN
# 3              NaN       NaN                     NaN
# 4              NaN       NaN                     NaN
# 5              NaN       NaN                     0.0
# 6              NaN       NaN                     NaN
# 7              NaN       NaN                     0.0
# 8              NaN       NaN                     NaN
# 9              NaN       NaN                     NaN
#
# [10 rows x 502 columns]

# %%
group_data = main.groupby('redcap_event_name')[['id_participant']].count()
group_data
# Out:
#                           id_participant
# redcap_event_name
# consent_initial_vi_arm_1            1228
# consent_initial_vi_arm_2              75
# sample_a_year_1_arm_1                401
# sample_a_year_2_arm_1                100
# sample_a_year_3_arm_1                 15
# sample_b_year_1_arm_1                185
# sample_b_year_2_arm_1                 26
# sample_b_year_3_arm_1                  2
# sample_c_year_1_arm_1                 15
# sample_c_year_2_arm_1                  5
# sample_d_year_1_arm_1                  1
# sample_d_year_2_arm_1                  1
# year_1_arm_1                         465
# year_1a_arm_2                         34
# year_2_arm_1                           1
# year_2_arm_2                           9
# year_2a_arm_2                          1

# %%
list_events = main['redcap_event_name'].unique()
list_events
# Out:
# array(['consent_initial_vi_arm_1', 'year_1_arm_1',
#        'sample_a_year_1_arm_1', 'sample_b_year_1_arm_1',
#        'sample_a_year_2_arm_1', 'sample_a_year_3_arm_1',
#        'sample_b_year_2_arm_1', 'sample_c_year_1_arm_1',
#        'sample_b_year_3_arm_1', 'consent_initial_vi_arm_2',
#        'year_1a_arm_2', 'sample_c_year_2_arm_1', 'year_2_arm_2',
#        'sample_d_year_1_arm_1', 'sample_d_year_2_arm_1', 'year_2_arm_1',
#        'year_2a_arm_2'], dtype=object)

# %%
output_pre = '../' 
for event in list_events:
    data = main[main['redcap_event_name'] == event]
    data.to_csv(output_pre + event + ".csv")
    
consent_files = [x for x in list_events if 'consent_initial' in x]

for f in consent_files:
    arm = pd.read_csv(output_pre + f + ".csv")
    arm_type = f.split('vi_')[-1]
    arm_files = [x for x in list_events if arm_type in x]
    for subfile in arm_files:
        sub =  pd.read_csv(output_pre + subfile + ".csv")
        print(sub.shape)
        print(sub.isnull().sum())
        sub.set_index('id_participant', inplace=True)
        sub.update(arm.set_index('id_participant'),overwrite=False)
        sub.reset_index()
        sub.to_csv(output_pre + subfile+ ".csv")
        #sub.to_csv(subfile+ ".csv")
# Out:
# (1228, 503)
# Unnamed: 0                          0
# id_participant                      0
# redcap_event_name                   0
# name_first                         53
# name_middle                       674
# name_last                          53
# dob                               116
# subject_sex                        60
# race                              565
# ethnicity                         554
# id_primary                         77
# id_secondary                     1187
# id_imsms                         1164
# id_med_record_number              200
# subject_group                      77
# recruitment_source                 77
# recruitment_source_other         1227
# enrollment_site                    76
# other_enrollment                 1106
# msdx_recruitment                  171
# msdx_current                      187
# medical_release                  1133
# msdx_validated                    326
# msdx_validated_upload            1216
# date_firstsx                      428
# age_firstsx                       443
# type_firstsx                      508
# date_msdx                         360
# method_msdx___1                     0
# method_msdx___2                     0
#                                  ...
# dmt_sixth_end                    1220
# dmt_seventh                      1221
# dmt_seventh_start                1222
# dmt_seventh_end                  1225
# dmt_eighth                       1224
# dmt_eighth_start                 1224
# dmt_eighth_end                   1228
# dmt_ninth                        1227
# dmt_ninth_start                  1228
# dmt_ninth_end                    1228
# dmt_tenth                        1227
# dmt_tenth_start                  1228
# dmt_tenth_end                    1228
# dmt_history_complete                0
# mri_screening_complete           1228
# mri_screening_eligible           1228
# mri_scan_research                1228
# mri_scan_clinical                1228
# mri_consent_how                  1228
# mri_date_electronic_sent         1228
# mri_date_mail_sent               1228
# mri_date_signed_consent          1228
# mri_version_consent_form         1228
# mri_version_date_consent_form    1228
# mri_consent_pdf                  1228
# t_mri_complete                   1228
# tdate_order                      1180
# tdate_completion                 1194
# notes_3t                         1228
# subtle_3t_mri_complete              0
# Length: 503, dtype: int64
# (465, 503)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       465
# name_middle                      465
# name_last                        465
# dob                              465
# subject_sex                      465
# race                             465
# ethnicity                        465
# id_primary                       465
# id_secondary                     465
# id_imsms                         465
# id_med_record_number             465
# subject_group                    465
# recruitment_source               465
# recruitment_source_other         465
# enrollment_site                  465
# other_enrollment                 465
# msdx_recruitment                 465
# msdx_current                     465
# medical_release                  465
# msdx_validated                   465
# msdx_validated_upload            465
# date_firstsx                     465
# age_firstsx                      465
# type_firstsx                     465
# date_msdx                        465
# method_msdx___1                  465
# method_msdx___2                  465
#                                 ...
# dmt_sixth_end                    465
# dmt_seventh                      465
# dmt_seventh_start                465
# dmt_seventh_end                  465
# dmt_eighth                       465
# dmt_eighth_start                 465
# dmt_eighth_end                   465
# dmt_ninth                        465
# dmt_ninth_start                  465
# dmt_ninth_end                    465
# dmt_tenth                        465
# dmt_tenth_start                  465
# dmt_tenth_end                    465
# dmt_history_complete             465
# mri_screening_complete           465
# mri_screening_eligible           465
# mri_scan_research                465
# mri_scan_clinical                465
# mri_consent_how                  465
# mri_date_electronic_sent         465
# mri_date_mail_sent               465
# mri_date_signed_consent          465
# mri_version_consent_form         465
# mri_version_date_consent_form    465
# mri_consent_pdf                  465
# t_mri_complete                   465
# tdate_order                      465
# tdate_completion                 465
# notes_3t                         465
# subtle_3t_mri_complete           465
# Length: 503, dtype: int64
# (401, 503)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       401
# name_middle                      401
# name_last                        401
# dob                              401
# subject_sex                      401
# race                             401
# ethnicity                        401
# id_primary                       401
# id_secondary                     401
# id_imsms                         401
# id_med_record_number             401
# subject_group                    401
# recruitment_source               401
# recruitment_source_other         401
# enrollment_site                  401
# other_enrollment                 401
# msdx_recruitment                 401
# msdx_current                     401
# medical_release                  401
# msdx_validated                   401
# msdx_validated_upload            401
# date_firstsx                     401
# age_firstsx                      401
# type_firstsx                     401
# date_msdx                        401
# method_msdx___1                  401
# method_msdx___2                  401
#                                 ...
# dmt_sixth_end                    401
# dmt_seventh                      401
# dmt_seventh_start                401
# dmt_seventh_end                  401
# dmt_eighth                       401
# dmt_eighth_start                 401
# dmt_eighth_end                   401
# dmt_ninth                        401
# dmt_ninth_start                  401
# dmt_ninth_end                    401
# dmt_tenth                        401
# dmt_tenth_start                  401
# dmt_tenth_end                    401
# dmt_history_complete             401
# mri_screening_complete           352
# mri_screening_eligible           354
# mri_scan_research                372
# mri_scan_clinical                378
# mri_consent_how                  346
# mri_date_electronic_sent         380
# mri_date_mail_sent               400
# mri_date_signed_consent          347
# mri_version_consent_form         345
# mri_version_date_consent_form    346
# mri_consent_pdf                  345
# t_mri_complete                     0
# tdate_order                      401
# tdate_completion                 401
# notes_3t                         401
# subtle_3t_mri_complete           401
# Length: 503, dtype: int64
# (185, 503)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       185
# name_middle                      185
# name_last                        185
# dob                              185
# subject_sex                      185
# race                             185
# ethnicity                        185
# id_primary                       185
# id_secondary                     185
# id_imsms                         185
# id_med_record_number             185
# subject_group                    185
# recruitment_source               185
# recruitment_source_other         185
# enrollment_site                  185
# other_enrollment                 185
# msdx_recruitment                 185
# msdx_current                     185
# medical_release                  185
# msdx_validated                   185
# msdx_validated_upload            185
# date_firstsx                     185
# age_firstsx                      185
# type_firstsx                     185
# date_msdx                        185
# method_msdx___1                  185
# method_msdx___2                  185
#                                 ...
# dmt_sixth_end                    185
# dmt_seventh                      185
# dmt_seventh_start                185
# dmt_seventh_end                  185
# dmt_eighth                       185
# dmt_eighth_start                 185
# dmt_eighth_end                   185
# dmt_ninth                        185
# dmt_ninth_start                  185
# dmt_ninth_end                    185
# dmt_tenth                        185
# dmt_tenth_start                  185
# dmt_tenth_end                    185
# dmt_history_complete             185
# mri_screening_complete           185
# mri_screening_eligible           185
# mri_scan_research                185
# mri_scan_clinical                185
# mri_consent_how                  185
# mri_date_electronic_sent         185
# mri_date_mail_sent               185
# mri_date_signed_consent          185
# mri_version_consent_form         185
# mri_version_date_consent_form    185
# mri_consent_pdf                  185
# t_mri_complete                     0
# tdate_order                      185
# tdate_completion                 185
# notes_3t                         185
# subtle_3t_mri_complete           185
# Length: 503, dtype: int64
# (100, 503)
# Unnamed: 0                         0
# id_participant                     0
# redcap_event_name                  0
# name_first                       100
# name_middle                      100
# name_last                        100
# dob                              100
# subject_sex                      100
# race                             100
# ethnicity                        100
# id_primary                       100
# id_secondary                     100
# id_imsms                         100
# id_med_record_number             100
# subject_group                    100
# recruitment_source               100
# recruitment_source_other         100
# enrollment_site                  100
# other_enrollment                 100
# msdx_recruitment                 100
# msdx_current                     100
# medical_release                  100
# msdx_validated                   100
# msdx_validated_upload            100
# date_firstsx                     100
# age_firstsx                      100
# type_firstsx                     100
# date_msdx                        100
# method_msdx___1                  100
# method_msdx___2                  100
#                                 ...
# dmt_sixth_end                    100
# dmt_seventh                      100
# dmt_seventh_start                100
# dmt_seventh_end                  100
# dmt_eighth                       100
# dmt_eighth_start                 100
# dmt_eighth_end                   100
# dmt_ninth                        100
# dmt_ninth_start                  100
# dmt_ninth_end                    100
# dmt_tenth                        100
# dmt_tenth_start                  100
# dmt_tenth_end                    100
# dmt_history_complete             100
# mri_screening_complete           100
# mri_screening_eligible           100
# mri_scan_research                100
# mri_scan_clinical                100
# mri_consent_how                  100
# mri_date_electronic_sent         100
# mri_date_mail_sent               100
# mri_date_signed_consent          100
# mri_version_consent_form         100
# mri_version_date_consent_form    100
# mri_consent_pdf                  100
# t_mri_complete                     0
# tdate_order                      100
# tdate_completion                 100
# notes_3t                         100
# subtle_3t_mri_complete           100
# Length: 503, dtype: int64
# (15, 503)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       15
# name_middle                      15
# name_last                        15
# dob                              15
# subject_sex                      15
# race                             15
# ethnicity                        15
# id_primary                       15
# id_secondary                     15
# id_imsms                         15
# id_med_record_number             15
# subject_group                    15
# recruitment_source               15
# recruitment_source_other         15
# enrollment_site                  15
# other_enrollment                 15
# msdx_recruitment                 15
# msdx_current                     15
# medical_release                  15
# msdx_validated                   15
# msdx_validated_upload            15
# date_firstsx                     15
# age_firstsx                      15
# type_firstsx                     15
# date_msdx                        15
# method_msdx___1                  15
# method_msdx___2                  15
#                                  ..
# dmt_sixth_end                    15
# dmt_seventh                      15
# dmt_seventh_start                15
# dmt_seventh_end                  15
# dmt_eighth                       15
# dmt_eighth_start                 15
# dmt_eighth_end                   15
# dmt_ninth                        15
# dmt_ninth_start                  15
# dmt_ninth_end                    15
# dmt_tenth                        15
# dmt_tenth_start                  15
# dmt_tenth_end                    15
# dmt_history_complete             15
# mri_screening_complete           15
# mri_screening_eligible           15
# mri_scan_research                15
# mri_scan_clinical                15
# mri_consent_how                  15
# mri_date_electronic_sent         15
# mri_date_mail_sent               15
# mri_date_signed_consent          15
# mri_version_consent_form         15
# mri_version_date_consent_form    15
# mri_consent_pdf                  15
# t_mri_complete                    0
# tdate_order                      15
# tdate_completion                 15
# notes_3t                         15
# subtle_3t_mri_complete           15
# Length: 503, dtype: int64
# (26, 503)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       26
# name_middle                      26
# name_last                        26
# dob                              26
# subject_sex                      26
# race                             26
# ethnicity                        26
# id_primary                       26
# id_secondary                     26
# id_imsms                         26
# id_med_record_number             26
# subject_group                    26
# recruitment_source               26
# recruitment_source_other         26
# enrollment_site                  26
# other_enrollment                 26
# msdx_recruitment                 26
# msdx_current                     26
# medical_release                  26
# msdx_validated                   26
# msdx_validated_upload            26
# date_firstsx                     26
# age_firstsx                      26
# type_firstsx                     26
# date_msdx                        26
# method_msdx___1                  26
# method_msdx___2                  26
#                                  ..
# dmt_sixth_end                    26
# dmt_seventh                      26
# dmt_seventh_start                26
# dmt_seventh_end                  26
# dmt_eighth                       26
# dmt_eighth_start                 26
# dmt_eighth_end                   26
# dmt_ninth                        26
# dmt_ninth_start                  26
# dmt_ninth_end                    26
# dmt_tenth                        26
# dmt_tenth_start                  26
# dmt_tenth_end                    26
# dmt_history_complete             26
# mri_screening_complete           26
# mri_screening_eligible           26
# mri_scan_research                26
# mri_scan_clinical                26
# mri_consent_how                  26
# mri_date_electronic_sent         26
# mri_date_mail_sent               26
# mri_date_signed_consent          26
# mri_version_consent_form         26
# mri_version_date_consent_form    26
# mri_consent_pdf                  26
# t_mri_complete                    0
# tdate_order                      26
# tdate_completion                 26
# notes_3t                         26
# subtle_3t_mri_complete           26
# Length: 503, dtype: int64
# (15, 503)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       15
# name_middle                      15
# name_last                        15
# dob                              15
# subject_sex                      15
# race                             15
# ethnicity                        15
# id_primary                       15
# id_secondary                     15
# id_imsms                         15
# id_med_record_number             15
# subject_group                    15
# recruitment_source               15
# recruitment_source_other         15
# enrollment_site                  15
# other_enrollment                 15
# msdx_recruitment                 15
# msdx_current                     15
# medical_release                  15
# msdx_validated                   15
# msdx_validated_upload            15
# date_firstsx                     15
# age_firstsx                      15
# type_firstsx                     15
# date_msdx                        15
# method_msdx___1                  15
# method_msdx___2                  15
#                                  ..
# dmt_sixth_end                    15
# dmt_seventh                      15
# dmt_seventh_start                15
# dmt_seventh_end                  15
# dmt_eighth                       15
# dmt_eighth_start                 15
# dmt_eighth_end                   15
# dmt_ninth                        15
# dmt_ninth_start                  15
# dmt_ninth_end                    15
# dmt_tenth                        15
# dmt_tenth_start                  15
# dmt_tenth_end                    15
# dmt_history_complete             15
# mri_screening_complete           15
# mri_screening_eligible           15
# mri_scan_research                15
# mri_scan_clinical                15
# mri_consent_how                  15
# mri_date_electronic_sent         15
# mri_date_mail_sent               15
# mri_date_signed_consent          15
# mri_version_consent_form         15
# mri_version_date_consent_form    15
# mri_consent_pdf                  15
# t_mri_complete                    0
# tdate_order                      15
# tdate_completion                 15
# notes_3t                         15
# subtle_3t_mri_complete           15
# Length: 503, dtype: int64
# (2, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       2
# name_middle                      2
# name_last                        2
# dob                              2
# subject_sex                      2
# race                             2
# ethnicity                        2
# id_primary                       2
# id_secondary                     2
# id_imsms                         2
# id_med_record_number             2
# subject_group                    2
# recruitment_source               2
# recruitment_source_other         2
# enrollment_site                  2
# other_enrollment                 2
# msdx_recruitment                 2
# msdx_current                     2
# medical_release                  2
# msdx_validated                   2
# msdx_validated_upload            2
# date_firstsx                     2
# age_firstsx                      2
# type_firstsx                     2
# date_msdx                        2
# method_msdx___1                  2
# method_msdx___2                  2
#                                 ..
# dmt_sixth_end                    2
# dmt_seventh                      2
# dmt_seventh_start                2
# dmt_seventh_end                  2
# dmt_eighth                       2
# dmt_eighth_start                 2
# dmt_eighth_end                   2
# dmt_ninth                        2
# dmt_ninth_start                  2
# dmt_ninth_end                    2
# dmt_tenth                        2
# dmt_tenth_start                  2
# dmt_tenth_end                    2
# dmt_history_complete             2
# mri_screening_complete           2
# mri_screening_eligible           2
# mri_scan_research                2
# mri_scan_clinical                2
# mri_consent_how                  2
# mri_date_electronic_sent         2
# mri_date_mail_sent               2
# mri_date_signed_consent          2
# mri_version_consent_form         2
# mri_version_date_consent_form    2
# mri_consent_pdf                  2
# t_mri_complete                   0
# tdate_order                      2
# tdate_completion                 2
# notes_3t                         2
# subtle_3t_mri_complete           2
# Length: 503, dtype: int64
# (5, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       5
# name_middle                      5
# name_last                        5
# dob                              5
# subject_sex                      5
# race                             5
# ethnicity                        5
# id_primary                       5
# id_secondary                     5
# id_imsms                         5
# id_med_record_number             5
# subject_group                    5
# recruitment_source               5
# recruitment_source_other         5
# enrollment_site                  5
# other_enrollment                 5
# msdx_recruitment                 5
# msdx_current                     5
# medical_release                  5
# msdx_validated                   5
# msdx_validated_upload            5
# date_firstsx                     5
# age_firstsx                      5
# type_firstsx                     5
# date_msdx                        5
# method_msdx___1                  5
# method_msdx___2                  5
#                                 ..
# dmt_sixth_end                    5
# dmt_seventh                      5
# dmt_seventh_start                5
# dmt_seventh_end                  5
# dmt_eighth                       5
# dmt_eighth_start                 5
# dmt_eighth_end                   5
# dmt_ninth                        5
# dmt_ninth_start                  5
# dmt_ninth_end                    5
# dmt_tenth                        5
# dmt_tenth_start                  5
# dmt_tenth_end                    5
# dmt_history_complete             5
# mri_screening_complete           5
# mri_screening_eligible           5
# mri_scan_research                5
# mri_scan_clinical                5
# mri_consent_how                  5
# mri_date_electronic_sent         5
# mri_date_mail_sent               5
# mri_date_signed_consent          5
# mri_version_consent_form         5
# mri_version_date_consent_form    5
# mri_consent_pdf                  5
# t_mri_complete                   0
# tdate_order                      5
# tdate_completion                 5
# notes_3t                         5
# subtle_3t_mri_complete           5
# Length: 503, dtype: int64
# (1, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       1
# name_middle                      1
# name_last                        1
# dob                              1
# subject_sex                      1
# race                             1
# ethnicity                        1
# id_primary                       1
# id_secondary                     1
# id_imsms                         1
# id_med_record_number             1
# subject_group                    1
# recruitment_source               1
# recruitment_source_other         1
# enrollment_site                  1
# other_enrollment                 1
# msdx_recruitment                 1
# msdx_current                     1
# medical_release                  1
# msdx_validated                   1
# msdx_validated_upload            1
# date_firstsx                     1
# age_firstsx                      1
# type_firstsx                     1
# date_msdx                        1
# method_msdx___1                  1
# method_msdx___2                  1
#                                 ..
# dmt_sixth_end                    1
# dmt_seventh                      1
# dmt_seventh_start                1
# dmt_seventh_end                  1
# dmt_eighth                       1
# dmt_eighth_start                 1
# dmt_eighth_end                   1
# dmt_ninth                        1
# dmt_ninth_start                  1
# dmt_ninth_end                    1
# dmt_tenth                        1
# dmt_tenth_start                  1
# dmt_tenth_end                    1
# dmt_history_complete             1
# mri_screening_complete           1
# mri_screening_eligible           1
# mri_scan_research                1
# mri_scan_clinical                1
# mri_consent_how                  1
# mri_date_electronic_sent         1
# mri_date_mail_sent               1
# mri_date_signed_consent          1
# mri_version_consent_form         1
# mri_version_date_consent_form    1
# mri_consent_pdf                  1
# t_mri_complete                   0
# tdate_order                      1
# tdate_completion                 1
# notes_3t                         1
# subtle_3t_mri_complete           1
# Length: 503, dtype: int64
# (1, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       1
# name_middle                      1
# name_last                        1
# dob                              1
# subject_sex                      1
# race                             1
# ethnicity                        1
# id_primary                       1
# id_secondary                     1
# id_imsms                         1
# id_med_record_number             1
# subject_group                    1
# recruitment_source               1
# recruitment_source_other         1
# enrollment_site                  1
# other_enrollment                 1
# msdx_recruitment                 1
# msdx_current                     1
# medical_release                  1
# msdx_validated                   1
# msdx_validated_upload            1
# date_firstsx                     1
# age_firstsx                      1
# type_firstsx                     1
# date_msdx                        1
# method_msdx___1                  1
# method_msdx___2                  1
#                                 ..
# dmt_sixth_end                    1
# dmt_seventh                      1
# dmt_seventh_start                1
# dmt_seventh_end                  1
# dmt_eighth                       1
# dmt_eighth_start                 1
# dmt_eighth_end                   1
# dmt_ninth                        1
# dmt_ninth_start                  1
# dmt_ninth_end                    1
# dmt_tenth                        1
# dmt_tenth_start                  1
# dmt_tenth_end                    1
# dmt_history_complete             1
# mri_screening_complete           1
# mri_screening_eligible           1
# mri_scan_research                1
# mri_scan_clinical                1
# mri_consent_how                  1
# mri_date_electronic_sent         1
# mri_date_mail_sent               1
# mri_date_signed_consent          1
# mri_version_consent_form         1
# mri_version_date_consent_form    1
# mri_consent_pdf                  1
# t_mri_complete                   0
# tdate_order                      1
# tdate_completion                 1
# notes_3t                         1
# subtle_3t_mri_complete           1
# Length: 503, dtype: int64
# (1, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       1
# name_middle                      1
# name_last                        1
# dob                              1
# subject_sex                      1
# race                             1
# ethnicity                        1
# id_primary                       1
# id_secondary                     1
# id_imsms                         1
# id_med_record_number             1
# subject_group                    1
# recruitment_source               1
# recruitment_source_other         1
# enrollment_site                  1
# other_enrollment                 1
# msdx_recruitment                 1
# msdx_current                     1
# medical_release                  1
# msdx_validated                   1
# msdx_validated_upload            1
# date_firstsx                     1
# age_firstsx                      1
# type_firstsx                     1
# date_msdx                        1
# method_msdx___1                  1
# method_msdx___2                  1
#                                 ..
# dmt_sixth_end                    1
# dmt_seventh                      1
# dmt_seventh_start                1
# dmt_seventh_end                  1
# dmt_eighth                       1
# dmt_eighth_start                 1
# dmt_eighth_end                   1
# dmt_ninth                        1
# dmt_ninth_start                  1
# dmt_ninth_end                    1
# dmt_tenth                        1
# dmt_tenth_start                  1
# dmt_tenth_end                    1
# dmt_history_complete             1
# mri_screening_complete           1
# mri_screening_eligible           1
# mri_scan_research                1
# mri_scan_clinical                1
# mri_consent_how                  1
# mri_date_electronic_sent         1
# mri_date_mail_sent               1
# mri_date_signed_consent          1
# mri_version_consent_form         1
# mri_version_date_consent_form    1
# mri_consent_pdf                  1
# t_mri_complete                   1
# tdate_order                      1
# tdate_completion                 1
# notes_3t                         1
# subtle_3t_mri_complete           1
# Length: 503, dtype: int64
# (75, 503)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                        0
# name_middle                      68
# name_last                         0
# dob                              25
# subject_sex                      44
# race                             63
# ethnicity                        63
# id_primary                        2
# id_secondary                     73
# id_imsms                         45
# id_med_record_number             42
# subject_group                     0
# recruitment_source               30
# recruitment_source_other         75
# enrollment_site                  10
# other_enrollment                 57
# msdx_recruitment                 19
# msdx_current                     25
# medical_release                  58
# msdx_validated                   60
# msdx_validated_upload            75
# date_firstsx                     74
# age_firstsx                      74
# type_firstsx                     74
# date_msdx                        75
# method_msdx___1                   0
# method_msdx___2                   0
#                                  ..
# dmt_sixth_end                    75
# dmt_seventh                      75
# dmt_seventh_start                75
# dmt_seventh_end                  75
# dmt_eighth                       75
# dmt_eighth_start                 75
# dmt_eighth_end                   75
# dmt_ninth                        75
# dmt_ninth_start                  75
# dmt_ninth_end                    75
# dmt_tenth                        75
# dmt_tenth_start                  75
# dmt_tenth_end                    75
# dmt_history_complete             75
# mri_screening_complete           74
# mri_screening_eligible           73
# mri_scan_research                75
# mri_scan_clinical                75
# mri_consent_how                  73
# mri_date_electronic_sent         75
# mri_date_mail_sent               75
# mri_date_signed_consent          74
# mri_version_consent_form         73
# mri_version_date_consent_form    73
# mri_consent_pdf                  73
# t_mri_complete                    0
# tdate_order                      75
# tdate_completion                 75
# notes_3t                         75
# subtle_3t_mri_complete           75
# Length: 503, dtype: int64
# (34, 503)
# Unnamed: 0                        0
# id_participant                    0
# redcap_event_name                 0
# name_first                       34
# name_middle                      34
# name_last                        34
# dob                              34
# subject_sex                      34
# race                             34
# ethnicity                        34
# id_primary                       34
# id_secondary                     34
# id_imsms                         34
# id_med_record_number             34
# subject_group                    34
# recruitment_source               34
# recruitment_source_other         34
# enrollment_site                  34
# other_enrollment                 34
# msdx_recruitment                 34
# msdx_current                     34
# medical_release                  34
# msdx_validated                   34
# msdx_validated_upload            34
# date_firstsx                     34
# age_firstsx                      34
# type_firstsx                     34
# date_msdx                        34
# method_msdx___1                  34
# method_msdx___2                  34
#                                  ..
# dmt_sixth_end                    34
# dmt_seventh                      34
# dmt_seventh_start                34
# dmt_seventh_end                  34
# dmt_eighth                       34
# dmt_eighth_start                 34
# dmt_eighth_end                   34
# dmt_ninth                        34
# dmt_ninth_start                  34
# dmt_ninth_end                    34
# dmt_tenth                        34
# dmt_tenth_start                  34
# dmt_tenth_end                    34
# dmt_history_complete             34
# mri_screening_complete           34
# mri_screening_eligible           34
# mri_scan_research                34
# mri_scan_clinical                34
# mri_consent_how                  34
# mri_date_electronic_sent         34
# mri_date_mail_sent               34
# mri_date_signed_consent          34
# mri_version_consent_form         34
# mri_version_date_consent_form    34
# mri_consent_pdf                  34
# t_mri_complete                   34
# tdate_order                      34
# tdate_completion                 34
# notes_3t                         34
# subtle_3t_mri_complete           34
# Length: 503, dtype: int64
# (9, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       9
# name_middle                      9
# name_last                        9
# dob                              9
# subject_sex                      9
# race                             9
# ethnicity                        9
# id_primary                       9
# id_secondary                     9
# id_imsms                         9
# id_med_record_number             9
# subject_group                    9
# recruitment_source               9
# recruitment_source_other         9
# enrollment_site                  9
# other_enrollment                 9
# msdx_recruitment                 9
# msdx_current                     9
# medical_release                  9
# msdx_validated                   9
# msdx_validated_upload            9
# date_firstsx                     9
# age_firstsx                      9
# type_firstsx                     9
# date_msdx                        9
# method_msdx___1                  9
# method_msdx___2                  9
#                                 ..
# dmt_sixth_end                    9
# dmt_seventh                      9
# dmt_seventh_start                9
# dmt_seventh_end                  9
# dmt_eighth                       9
# dmt_eighth_start                 9
# dmt_eighth_end                   9
# dmt_ninth                        9
# dmt_ninth_start                  9
# dmt_ninth_end                    9
# dmt_tenth                        9
# dmt_tenth_start                  9
# dmt_tenth_end                    9
# dmt_history_complete             9
# mri_screening_complete           9
# mri_screening_eligible           9
# mri_scan_research                9
# mri_scan_clinical                9
# mri_consent_how                  9
# mri_date_electronic_sent         9
# mri_date_mail_sent               9
# mri_date_signed_consent          9
# mri_version_consent_form         9
# mri_version_date_consent_form    9
# mri_consent_pdf                  9
# t_mri_complete                   9
# tdate_order                      9
# tdate_completion                 9
# notes_3t                         9
# subtle_3t_mri_complete           9
# Length: 503, dtype: int64
# (1, 503)
# Unnamed: 0                       0
# id_participant                   0
# redcap_event_name                0
# name_first                       1
# name_middle                      1
# name_last                        1
# dob                              1
# subject_sex                      1
# race                             1
# ethnicity                        1
# id_primary                       1
# id_secondary                     1
# id_imsms                         1
# id_med_record_number             1
# subject_group                    1
# recruitment_source               1
# recruitment_source_other         1
# enrollment_site                  1
# other_enrollment                 1
# msdx_recruitment                 1
# msdx_current                     1
# medical_release                  1
# msdx_validated                   1
# msdx_validated_upload            1
# date_firstsx                     1
# age_firstsx                      1
# type_firstsx                     1
# date_msdx                        1
# method_msdx___1                  1
# method_msdx___2                  1
#                                 ..
# dmt_sixth_end                    1
# dmt_seventh                      1
# dmt_seventh_start                1
# dmt_seventh_end                  1
# dmt_eighth                       1
# dmt_eighth_start                 1
# dmt_eighth_end                   1
# dmt_ninth                        1
# dmt_ninth_start                  1
# dmt_ninth_end                    1
# dmt_tenth                        1
# dmt_tenth_start                  1
# dmt_tenth_end                    1
# dmt_history_complete             1
# mri_screening_complete           1
# mri_screening_eligible           1
# mri_scan_research                1
# mri_scan_clinical                1
# mri_consent_how                  1
# mri_date_electronic_sent         1
# mri_date_mail_sent               1
# mri_date_signed_consent          1
# mri_version_consent_form         1
# mri_version_date_consent_form    1
# mri_consent_pdf                  1
# t_mri_complete                   1
# tdate_order                      1
# tdate_completion                 1
# notes_3t                         1
# subtle_3t_mri_complete           1
# Length: 503, dtype: int64

# %%
mainfile = pd.read_csv(output_pre + list_events[0] + '.csv')
other_files = list_events[1:]
for file in other_files:
    subfile = pd.read_csv(output_pre + file + ".csv")
    mainfile = pd.concat([mainfile, subfile],sort=False)

# %%
mainfile.shape
list(mainfile)
# Out:
# ['id_participant',
#  'Unnamed: 0',
#  'redcap_event_name',
#  'name_first',
#  'name_middle',
#  'name_last',
#  'dob',
#  'subject_sex',
#  'race',
#  'ethnicity',
#  'id_primary',
#  'id_secondary',
#  'id_imsms',
#  'id_med_record_number',
#  'subject_group',
#  'recruitment_source',
#  'recruitment_source_other',
#  'enrollment_site',
#  'other_enrollment',
#  'msdx_recruitment',
#  'msdx_current',
#  'medical_release',
#  'msdx_validated',
#  'msdx_validated_upload',
#  'date_firstsx',
#  'age_firstsx',
#  'type_firstsx',
#  'date_msdx',
#  'method_msdx___1',
#  'method_msdx___2',
#  'method_msdx___3',
#  'method_msdx___4',
#  'msdx_documentation',
#  'dmt_current___1',
#  'dmt_current___2',
#  'dmt_current___3',
#  'dmt_current___4',
#  'dmt_current___5',
#  'dmt_current___6',
#  'dmt_current___12',
#  'dmt_current___7',
#  'dmt_current___13',
#  'dmt_current___14',
#  'dmt_current___8',
#  'dmt_current___16',
#  'dmt_current___9',
#  'dmt_current___10',
#  'dmt_current___15',
#  'dmt_current___11',
#  'dmt_current___99',
#  'dmt_duration',
#  'dmt_current_other',
#  'address_current',
#  'address_current_2',
#  'address_current_3',
#  'state_current',
#  'zipcode_current',
#  'phone1',
#  'phone2',
#  'email1',
#  'email2',
#  'contact_method___1',
#  'contact_method___2',
#  'contact_method___3',
#  'contact1_first',
#  'contact1_last',
#  'contact1_relationship',
#  'contact1_phone1',
#  'contact1_phone_2',
#  'contact1_email',
#  'contact1_address',
#  'contact2_first',
#  'contact2_last',
#  'contact2_relationship',
#  'contact2_phone1',
#  'contact2_phone2',
#  'contact2_email',
#  'contact2_address',
#  'additional_notes',
#  'basic_information_complete',
#  'consent_age',
#  'consent_ability',
#  'assent_ability',
#  'consent_parent',
#  'consented_how',
#  'date_electronic_sent',
#  'date_mail_sent',
#  'date_signed_consent',
#  'version_consent_form',
#  'version_date_consent_form',
#  'consent_pdf',
#  'consent_complete',
#  'cohab',
#  'cohab_enroll___1',
#  'cohab_enroll___0',
#  'cohab_enroll___9',
#  'cohab_id',
#  'imsms_stat',
#  'cohabitant_complete',
#  'pq1_sent',
#  'pq1_completed',
#  'primary_questionnaire_complete',
#  'sro1_sent',
#  'sro1_completed',
#  'self_reported_outcome_questionnaire_complete',
#  'blood1_date',
#  'blood1_collect_time',
#  'blood1_amount',
#  'blood1_dmt',
#  'blood1_dmt_detail',
#  'blood1_dmt_other',
#  'blood1_dmt_duration',
#  'blood1_pddsv2',
#  'blood_pddsv2_uc',
#  'blood1_relapse_number',
#  'blood1_relapse_1date',
#  'blood1_relapse_1type',
#  'blood1_relapse_2date',
#  'blood1_relapse_2type',
#  'blood1_relapse_3date',
#  'blood1_relapse_3type',
#  'blood1_relapse_4date',
#  'blood1_relapse_4type',
#  'blood1_relapse_5date',
#  'blood1_relapse_5type',
#  'blood1_relapse_6date',
#  'blood1_relapse_6type',
#  'blood1_relapse_7date',
#  'blood1_relapse_7type',
#  'blood1_relapse_8date',
#  'blood1_relapse_8type',
#  'blood1_relapse_9date',
#  'blood1_relapse_9type',
#  'blood1_relapse_10date',
#  'blood1_relapse_10type',
#  'blood1_ab',
#  'blood1_st',
#  'blood1_aliquot_time',
#  'blood1_dna',
#  'blood1_dnanum',
#  'dna1_aliquot_time_1',
#  'blood1_dnacon',
#  'blood1_dnaamt1',
#  'dna1_aliquot_time_2',
#  'blood1_dnacon_2',
#  'blood1_dnaamt2',
#  'dna1_aliquot_time_3',
#  'blood1_dnaamt3',
#  'blood1_dnacon_3',
#  'blood1_cfdna',
#  'blood1_cfdna_time',
#  'blood1_cfdna_bcnum',
#  'blood1_cfdna_bc_tubetype1',
#  'blood1_cfdna_bc_vol1',
#  'blood1_cfdna_bc_tubetype2',
#  'blood1_cfdna_bc_vol2',
#  'blood1_cfdna_bc_tubetype3',
#  'blood1_cfdna_bc_vol3',
#  'blood1_cfdna_bc_tubetype4',
#  'blood1_cfdna_bc_vol4',
#  'blood1_cfdna_bc_tubetype5',
#  'blood1_cfdna_bc_vol5',
#  'blood1_cfdna_plasmanum',
#  'blood1_cfdna_plasma1',
#  'blood1_cfdna_plasma_vial1',
#  'blood1_cfdna_plasma2',
#  'blood1_cfdna_plasma_vial2',
#  'blood1_cfdna_plasma3',
#  'blood1_cfdna_plasma_vial3',
#  'blood1_cfdna_plasma4',
#  'blood1_cfdna_plasma_vial4',
#  'blood1_cfdna_plasma5',
#  'blood1_cfdna_plasma_vial5',
#  'blood1_pr',
#  'blood1_biobank',
#  'blood1_serum',
#  'blood1_plasma',
#  'blood1_cell',
#  'blood1_buffycoat',
#  'blood1_cellnum',
#  'blood1_imsms',
#  'blood1_imsmsserum',
#  'blood1_imsmsplasma',
#  'blood1_imsmscells',
#  'blood1_imsmscellnum',
#  'blood_sample_complete',
#  'stool1_screening',
#  'stool1_screening_how',
#  'stool_eligibile',
#  'stool_label1',
#  'stool_label2',
#  'proband_control',
#  'partner_studyid',
#  'imsms_dmt_detail',
#  'imsms_other_detail',
#  'imsms_eligibility',
#  'stool0_kitout_date',
#  'stool0a_collection_date',
#  'stool0b_collection_date',
#  'subjectq_completed_date',
#  'ffq_sent',
#  'ffq_date',
#  'ucsf_clinical_questionnaire',
#  'ucsf_shipped_date',
#  'stool_dmt',
#  'stool_dmt_detail',
#  'stool_dmt_other',
#  'stool_dmt_duration',
#  'stool_pddsv2',
#  'stool_pddsv2_uc',
#  'stool_relapse_number',
#  'stool_relapse_1date',
#  'stool_relapse_1type',
#  'stool_relapse_2date',
#  'stool_relapse_2type',
#  'stool_relapse_3date',
#  'stool_relapse_3type',
#  'stool_relapse_4date',
#  'stool_relapse_4type',
#  'stool_relapse_5date',
#  'stool_relapse_5type',
#  'stool_relapse_6date',
#  'stool_relapse_6type',
#  'stool_relapse_7date',
#  'stool_relapse_7type',
#  'stool_relapse_8date',
#  'stool_relapse_8type',
#  'stool_relapse_9date',
#  'stool_relapse_9type',
#  'stool_relapse_10date',
#  'stool_relapse_10type',
#  'promoteq_compete',
#  'promote_ffq_sent',
#  'promote_ffq_complete',
#  'stool1_kitout_date',
#  'collection1a_date',
#  'stooletoh',
#  'stooltemp',
#  'weight1_sample1',
#  'weight2_sample1',
#  'weight_3_sample1',
#  'weight4_sample1',
#  'weight5_sample1',
#  'weight6_sample1',
#  'collection1b_date',
#  'weight1_sample2',
#  'weight2_sample2',
#  'weight_3_sample2',
#  'weight4_sample2',
#  'weight5_sample2',
#  'weight6_sample2',
#  'stool_sample_complete',
#  'urine1_kitout_date',
#  'urine1_collection_date',
#  'urine_biobanking',
#  'urine_sample_complete',
#  'saliva1_kitout_date',
#  'saliva1_collection_date',
#  'saliva_biobanking',
#  'saliva_sample_complete',
#  'csf_date',
#  'csf_dmt',
#  'csf_dmt_type',
#  'csf_dmt_other',
#  'csf_dmt_duration',
#  'csf_pddsv2',
#  'csf_pddsv2_uc',
#  'csf_amount_1',
#  'csf_amount_2',
#  'csf_amount_3',
#  'csf_storage',
#  'csf_sample_complete',
#  'dna_date_collected',
#  'dna_quantity',
#  'dna_storage',
#  'dna_sample_complete',
#  'sdmt_date',
#  'sdmt_score',
#  'sdmt_percentage',
#  'sdmt_documentation',
#  'pasat_date',
#  'pasat_form',
#  'pasat_score',
#  'pasat_documentation',
#  'hpt_date',
#  'peg_dominant_hand',
#  'peg_dom1',
#  'pegdom_circumstances',
#  'pegdom_other',
#  'peg_dom2',
#  'pegdom2_circumstances',
#  'pegdom2_other',
#  'peg_nondom1',
#  'pegnondom1_circumstances',
#  'pegnondom1_other',
#  'peg_nondom2',
#  'pegnondom2_circumstances',
#  'pegnondom2_other',
#  'peg_2trials',
#  'peg_repeat_reason',
#  'peg_repeat_other',
#  'peg_documentation',
#  'footwalk_date',
#  't25w_assistance',
#  't25w_device',
#  't25w1',
#  't25w1_circumstances',
#  't25w1_other',
#  't25w1_repetition',
#  't25w2',
#  't25w2_circumstances',
#  't25wl2_other',
#  't25w2_repetition',
#  't25w_completion',
#  't25w_completion_reason',
#  'documents_msfc',
#  'tug_date',
#  'tug1_time',
#  'tug2_time',
#  'tug_observation___0',
#  'tug_observation___1',
#  'tug_observation___2',
#  'tug_observation___3',
#  'tug_observation___4',
#  'tug_observation___5',
#  'tug_observation___6',
#  'tug_observation___7',
#  'documents_tug',
#  'visual_acuity_date',
#  'visual_acuity_hc_right',
#  'visual_acuity_hc_left',
#  'visual_acuity_hc_binocular',
#  'visual_acuity_lc_right',
#  'visual_acuity_lc_left',
#  'visual_acuity_lc_binocular',
#  'mri_current',
#  'mri_results',
#  'functional_testing_complete',
#  'edss_score',
#  'edss_date',
#  'documents_edss',
#  'edss_complete',
#  'sensor_username',
#  'sensor_password',
#  'sensor_given',
#  'sensor_received',
#  'sensor_log',
#  'sensor_msrsr',
#  'sensor_sessions',
#  'sensor_wake',
#  'sensor_sleep',
#  'sensor_pdds',
#  'sensor_msrsr_walking1',
#  'sensor_msrsr_arms1',
#  'sensor_msrsr_vision1',
#  'sensor_msrsr_speech1',
#  'sensor_msrsr_swallowing1',
#  'sensor_msrsr_cog1',
#  'sensor_msrsr_sensation1',
#  'sensor_msrsr_bladder_bowel1',
#  'sensor_wake_2',
#  'sensor_sleep_2',
#  'sensor_wake_3',
#  'sensor_sleep_3',
#  'sensor_wake_4',
#  'sensor_sleep_4',
#  'sensor_wake_5',
#  'sensor_sleep_5',
#  'sensor_wake_6',
#  'sensor_sleep_6',
#  'sensor_wake_7',
#  'sensor_sleep_7',
#  'sensor_wake_8',
#  'sensor_sleep_8',
#  'sensor_pdds_8',
#  'sensor_wake_9',
#  'sensor_sleep_9',
#  'sensor_wake_10',
#  'sensor_sleep_10',
#  'sensor_wake_11',
#  'sensor_sleep_11',
#  'sensor_wake_12',
#  'sensor_sleep_12',
#  'sensor_wake_13',
#  'sensor_sleep_13',
#  'sensor_wake_14',
#  'sensor_sleep_14',
#  'sensor_wake_15',
#  'sensor_sleep_15',
#  'sensor_pdds_15',
#  'sensor_wake_16',
#  'sensor_sleep_16',
#  'sensor_wake_17',
#  'sensor_sleep_17',
#  'sensor_wake_18',
#  'sensor_sleep_18',
#  'sensor_wake_19',
#  'sensor_sleep_19',
#  'sensor_wake_20',
#  'sensor_sleep_20',
#  'sensor_wake_21',
#  'sensor_sleep_21',
#  'sensor_wake_22',
#  'sensor_sleep_22',
#  'sensor_pdds_22',
#  'sensor_wake_23',
#  'sensor_sleep_23',
#  'sensor_wake_24',
#  'sensor_sleep_24',
#  'sensor_wake_25',
#  'sensor_sleep_25',
#  'sensor_wake_26',
#  'sensor_sleep_26',
#  'sensor_wake_27',
#  'sensor_sleep_27',
#  'sensor_wake_28',
#  'sensor_sleep_28',
#  'sensor_wake_29',
#  'sensor_sleep_29',
#  'sensor_pdds_29',
#  'sensor_wake_30',
#  'sensor_sleep_30',
#  'sensor_wake_31',
#  'sensor_sleep_31',
#  'sensor_complete',
#  'cogstate_link_sent',
#  'cogstate_date',
#  'documents_cogstate',
#  'cognitive_testing_complete',
#  'snq_link_date',
#  'snq_date',
#  'socialnetwork_upload',
#  'social_network_complete',
#  'relapse_number',
#  'relapse_first_date',
#  'relapse_first_type',
#  'relapse_second_date',
#  'relapse_second_type',
#  'relapse_third_date',
#  'relapse_third_type',
#  'relapse_fourth_date',
#  'relapse_fourth_type',
#  'relapse_fifth_date',
#  'relapse_fifth_type',
#  'relapse_sixth_date',
#  'relapse_sixth_type',
#  'relapse_seventh_date',
#  'relapse_seventh_type',
#  'relapse_eighth_date',
#  'relapse_eighth_type',
#  'relapse_ninth_date',
#  'relapse_ninth_type',
#  'relapse_tenth_date',
#  'relapse_tenth_type',
#  'relapse_history_complete',
#  'dmt_number',
#  'dmt_first',
#  'dmt_first_start',
#  'dmt_first_end',
#  'dmt_second',
#  'dmt_second_start',
#  'dmt_second_end',
#  'dmt_third',
#  'dmt_third_start',
#  'dmt_third_end',
#  'dmt_fourth',
#  'dmt_fourth_start',
#  'dmt_fourth_end',
#  'dmt_fifth',
#  'dmt_fifth_start',
#  'dmt_fifth_end',
#  'dmt_sixth',
#  'dmt_sixth_start',
#  'dmt_sixth_end',
#  'dmt_seventh',
#  'dmt_seventh_start',
#  'dmt_seventh_end',
#  'dmt_eighth',
#  'dmt_eighth_start',
#  'dmt_eighth_end',
#  'dmt_ninth',
#  'dmt_ninth_start',
#  'dmt_ninth_end',
#  'dmt_tenth',
#  'dmt_tenth_start',
#  'dmt_tenth_end',
#  'dmt_history_complete',
#  'mri_screening_complete',
#  'mri_screening_eligible',
#  'mri_scan_research',
#  'mri_scan_clinical',
#  'mri_consent_how',
#  'mri_date_electronic_sent',
#  'mri_date_mail_sent',
#  'mri_date_signed_consent',
#  'mri_version_consent_form',
#  'mri_version_date_consent_form',
#  'mri_consent_pdf',
#  't_mri_complete',
#  'tdate_order',
#  'tdate_completion',
#  'notes_3t',
#  'subtle_3t_mri_complete']

# %%
del mainfile['Unnamed: 0']
list(mainfile)
# Out:
# ['id_participant',
#  'redcap_event_name',
#  'name_first',
#  'name_middle',
#  'name_last',
#  'dob',
#  'subject_sex',
#  'race',
#  'ethnicity',
#  'id_primary',
#  'id_secondary',
#  'id_imsms',
#  'id_med_record_number',
#  'subject_group',
#  'recruitment_source',
#  'recruitment_source_other',
#  'enrollment_site',
#  'other_enrollment',
#  'msdx_recruitment',
#  'msdx_current',
#  'medical_release',
#  'msdx_validated',
#  'msdx_validated_upload',
#  'date_firstsx',
#  'age_firstsx',
#  'type_firstsx',
#  'date_msdx',
#  'method_msdx___1',
#  'method_msdx___2',
#  'method_msdx___3',
#  'method_msdx___4',
#  'msdx_documentation',
#  'dmt_current___1',
#  'dmt_current___2',
#  'dmt_current___3',
#  'dmt_current___4',
#  'dmt_current___5',
#  'dmt_current___6',
#  'dmt_current___12',
#  'dmt_current___7',
#  'dmt_current___13',
#  'dmt_current___14',
#  'dmt_current___8',
#  'dmt_current___16',
#  'dmt_current___9',
#  'dmt_current___10',
#  'dmt_current___15',
#  'dmt_current___11',
#  'dmt_current___99',
#  'dmt_duration',
#  'dmt_current_other',
#  'address_current',
#  'address_current_2',
#  'address_current_3',
#  'state_current',
#  'zipcode_current',
#  'phone1',
#  'phone2',
#  'email1',
#  'email2',
#  'contact_method___1',
#  'contact_method___2',
#  'contact_method___3',
#  'contact1_first',
#  'contact1_last',
#  'contact1_relationship',
#  'contact1_phone1',
#  'contact1_phone_2',
#  'contact1_email',
#  'contact1_address',
#  'contact2_first',
#  'contact2_last',
#  'contact2_relationship',
#  'contact2_phone1',
#  'contact2_phone2',
#  'contact2_email',
#  'contact2_address',
#  'additional_notes',
#  'basic_information_complete',
#  'consent_age',
#  'consent_ability',
#  'assent_ability',
#  'consent_parent',
#  'consented_how',
#  'date_electronic_sent',
#  'date_mail_sent',
#  'date_signed_consent',
#  'version_consent_form',
#  'version_date_consent_form',
#  'consent_pdf',
#  'consent_complete',
#  'cohab',
#  'cohab_enroll___1',
#  'cohab_enroll___0',
#  'cohab_enroll___9',
#  'cohab_id',
#  'imsms_stat',
#  'cohabitant_complete',
#  'pq1_sent',
#  'pq1_completed',
#  'primary_questionnaire_complete',
#  'sro1_sent',
#  'sro1_completed',
#  'self_reported_outcome_questionnaire_complete',
#  'blood1_date',
#  'blood1_collect_time',
#  'blood1_amount',
#  'blood1_dmt',
#  'blood1_dmt_detail',
#  'blood1_dmt_other',
#  'blood1_dmt_duration',
#  'blood1_pddsv2',
#  'blood_pddsv2_uc',
#  'blood1_relapse_number',
#  'blood1_relapse_1date',
#  'blood1_relapse_1type',
#  'blood1_relapse_2date',
#  'blood1_relapse_2type',
#  'blood1_relapse_3date',
#  'blood1_relapse_3type',
#  'blood1_relapse_4date',
#  'blood1_relapse_4type',
#  'blood1_relapse_5date',
#  'blood1_relapse_5type',
#  'blood1_relapse_6date',
#  'blood1_relapse_6type',
#  'blood1_relapse_7date',
#  'blood1_relapse_7type',
#  'blood1_relapse_8date',
#  'blood1_relapse_8type',
#  'blood1_relapse_9date',
#  'blood1_relapse_9type',
#  'blood1_relapse_10date',
#  'blood1_relapse_10type',
#  'blood1_ab',
#  'blood1_st',
#  'blood1_aliquot_time',
#  'blood1_dna',
#  'blood1_dnanum',
#  'dna1_aliquot_time_1',
#  'blood1_dnacon',
#  'blood1_dnaamt1',
#  'dna1_aliquot_time_2',
#  'blood1_dnacon_2',
#  'blood1_dnaamt2',
#  'dna1_aliquot_time_3',
#  'blood1_dnaamt3',
#  'blood1_dnacon_3',
#  'blood1_cfdna',
#  'blood1_cfdna_time',
#  'blood1_cfdna_bcnum',
#  'blood1_cfdna_bc_tubetype1',
#  'blood1_cfdna_bc_vol1',
#  'blood1_cfdna_bc_tubetype2',
#  'blood1_cfdna_bc_vol2',
#  'blood1_cfdna_bc_tubetype3',
#  'blood1_cfdna_bc_vol3',
#  'blood1_cfdna_bc_tubetype4',
#  'blood1_cfdna_bc_vol4',
#  'blood1_cfdna_bc_tubetype5',
#  'blood1_cfdna_bc_vol5',
#  'blood1_cfdna_plasmanum',
#  'blood1_cfdna_plasma1',
#  'blood1_cfdna_plasma_vial1',
#  'blood1_cfdna_plasma2',
#  'blood1_cfdna_plasma_vial2',
#  'blood1_cfdna_plasma3',
#  'blood1_cfdna_plasma_vial3',
#  'blood1_cfdna_plasma4',
#  'blood1_cfdna_plasma_vial4',
#  'blood1_cfdna_plasma5',
#  'blood1_cfdna_plasma_vial5',
#  'blood1_pr',
#  'blood1_biobank',
#  'blood1_serum',
#  'blood1_plasma',
#  'blood1_cell',
#  'blood1_buffycoat',
#  'blood1_cellnum',
#  'blood1_imsms',
#  'blood1_imsmsserum',
#  'blood1_imsmsplasma',
#  'blood1_imsmscells',
#  'blood1_imsmscellnum',
#  'blood_sample_complete',
#  'stool1_screening',
#  'stool1_screening_how',
#  'stool_eligibile',
#  'stool_label1',
#  'stool_label2',
#  'proband_control',
#  'partner_studyid',
#  'imsms_dmt_detail',
#  'imsms_other_detail',
#  'imsms_eligibility',
#  'stool0_kitout_date',
#  'stool0a_collection_date',
#  'stool0b_collection_date',
#  'subjectq_completed_date',
#  'ffq_sent',
#  'ffq_date',
#  'ucsf_clinical_questionnaire',
#  'ucsf_shipped_date',
#  'stool_dmt',
#  'stool_dmt_detail',
#  'stool_dmt_other',
#  'stool_dmt_duration',
#  'stool_pddsv2',
#  'stool_pddsv2_uc',
#  'stool_relapse_number',
#  'stool_relapse_1date',
#  'stool_relapse_1type',
#  'stool_relapse_2date',
#  'stool_relapse_2type',
#  'stool_relapse_3date',
#  'stool_relapse_3type',
#  'stool_relapse_4date',
#  'stool_relapse_4type',
#  'stool_relapse_5date',
#  'stool_relapse_5type',
#  'stool_relapse_6date',
#  'stool_relapse_6type',
#  'stool_relapse_7date',
#  'stool_relapse_7type',
#  'stool_relapse_8date',
#  'stool_relapse_8type',
#  'stool_relapse_9date',
#  'stool_relapse_9type',
#  'stool_relapse_10date',
#  'stool_relapse_10type',
#  'promoteq_compete',
#  'promote_ffq_sent',
#  'promote_ffq_complete',
#  'stool1_kitout_date',
#  'collection1a_date',
#  'stooletoh',
#  'stooltemp',
#  'weight1_sample1',
#  'weight2_sample1',
#  'weight_3_sample1',
#  'weight4_sample1',
#  'weight5_sample1',
#  'weight6_sample1',
#  'collection1b_date',
#  'weight1_sample2',
#  'weight2_sample2',
#  'weight_3_sample2',
#  'weight4_sample2',
#  'weight5_sample2',
#  'weight6_sample2',
#  'stool_sample_complete',
#  'urine1_kitout_date',
#  'urine1_collection_date',
#  'urine_biobanking',
#  'urine_sample_complete',
#  'saliva1_kitout_date',
#  'saliva1_collection_date',
#  'saliva_biobanking',
#  'saliva_sample_complete',
#  'csf_date',
#  'csf_dmt',
#  'csf_dmt_type',
#  'csf_dmt_other',
#  'csf_dmt_duration',
#  'csf_pddsv2',
#  'csf_pddsv2_uc',
#  'csf_amount_1',
#  'csf_amount_2',
#  'csf_amount_3',
#  'csf_storage',
#  'csf_sample_complete',
#  'dna_date_collected',
#  'dna_quantity',
#  'dna_storage',
#  'dna_sample_complete',
#  'sdmt_date',
#  'sdmt_score',
#  'sdmt_percentage',
#  'sdmt_documentation',
#  'pasat_date',
#  'pasat_form',
#  'pasat_score',
#  'pasat_documentation',
#  'hpt_date',
#  'peg_dominant_hand',
#  'peg_dom1',
#  'pegdom_circumstances',
#  'pegdom_other',
#  'peg_dom2',
#  'pegdom2_circumstances',
#  'pegdom2_other',
#  'peg_nondom1',
#  'pegnondom1_circumstances',
#  'pegnondom1_other',
#  'peg_nondom2',
#  'pegnondom2_circumstances',
#  'pegnondom2_other',
#  'peg_2trials',
#  'peg_repeat_reason',
#  'peg_repeat_other',
#  'peg_documentation',
#  'footwalk_date',
#  't25w_assistance',
#  't25w_device',
#  't25w1',
#  't25w1_circumstances',
#  't25w1_other',
#  't25w1_repetition',
#  't25w2',
#  't25w2_circumstances',
#  't25wl2_other',
#  't25w2_repetition',
#  't25w_completion',
#  't25w_completion_reason',
#  'documents_msfc',
#  'tug_date',
#  'tug1_time',
#  'tug2_time',
#  'tug_observation___0',
#  'tug_observation___1',
#  'tug_observation___2',
#  'tug_observation___3',
#  'tug_observation___4',
#  'tug_observation___5',
#  'tug_observation___6',
#  'tug_observation___7',
#  'documents_tug',
#  'visual_acuity_date',
#  'visual_acuity_hc_right',
#  'visual_acuity_hc_left',
#  'visual_acuity_hc_binocular',
#  'visual_acuity_lc_right',
#  'visual_acuity_lc_left',
#  'visual_acuity_lc_binocular',
#  'mri_current',
#  'mri_results',
#  'functional_testing_complete',
#  'edss_score',
#  'edss_date',
#  'documents_edss',
#  'edss_complete',
#  'sensor_username',
#  'sensor_password',
#  'sensor_given',
#  'sensor_received',
#  'sensor_log',
#  'sensor_msrsr',
#  'sensor_sessions',
#  'sensor_wake',
#  'sensor_sleep',
#  'sensor_pdds',
#  'sensor_msrsr_walking1',
#  'sensor_msrsr_arms1',
#  'sensor_msrsr_vision1',
#  'sensor_msrsr_speech1',
#  'sensor_msrsr_swallowing1',
#  'sensor_msrsr_cog1',
#  'sensor_msrsr_sensation1',
#  'sensor_msrsr_bladder_bowel1',
#  'sensor_wake_2',
#  'sensor_sleep_2',
#  'sensor_wake_3',
#  'sensor_sleep_3',
#  'sensor_wake_4',
#  'sensor_sleep_4',
#  'sensor_wake_5',
#  'sensor_sleep_5',
#  'sensor_wake_6',
#  'sensor_sleep_6',
#  'sensor_wake_7',
#  'sensor_sleep_7',
#  'sensor_wake_8',
#  'sensor_sleep_8',
#  'sensor_pdds_8',
#  'sensor_wake_9',
#  'sensor_sleep_9',
#  'sensor_wake_10',
#  'sensor_sleep_10',
#  'sensor_wake_11',
#  'sensor_sleep_11',
#  'sensor_wake_12',
#  'sensor_sleep_12',
#  'sensor_wake_13',
#  'sensor_sleep_13',
#  'sensor_wake_14',
#  'sensor_sleep_14',
#  'sensor_wake_15',
#  'sensor_sleep_15',
#  'sensor_pdds_15',
#  'sensor_wake_16',
#  'sensor_sleep_16',
#  'sensor_wake_17',
#  'sensor_sleep_17',
#  'sensor_wake_18',
#  'sensor_sleep_18',
#  'sensor_wake_19',
#  'sensor_sleep_19',
#  'sensor_wake_20',
#  'sensor_sleep_20',
#  'sensor_wake_21',
#  'sensor_sleep_21',
#  'sensor_wake_22',
#  'sensor_sleep_22',
#  'sensor_pdds_22',
#  'sensor_wake_23',
#  'sensor_sleep_23',
#  'sensor_wake_24',
#  'sensor_sleep_24',
#  'sensor_wake_25',
#  'sensor_sleep_25',
#  'sensor_wake_26',
#  'sensor_sleep_26',
#  'sensor_wake_27',
#  'sensor_sleep_27',
#  'sensor_wake_28',
#  'sensor_sleep_28',
#  'sensor_wake_29',
#  'sensor_sleep_29',
#  'sensor_pdds_29',
#  'sensor_wake_30',
#  'sensor_sleep_30',
#  'sensor_wake_31',
#  'sensor_sleep_31',
#  'sensor_complete',
#  'cogstate_link_sent',
#  'cogstate_date',
#  'documents_cogstate',
#  'cognitive_testing_complete',
#  'snq_link_date',
#  'snq_date',
#  'socialnetwork_upload',
#  'social_network_complete',
#  'relapse_number',
#  'relapse_first_date',
#  'relapse_first_type',
#  'relapse_second_date',
#  'relapse_second_type',
#  'relapse_third_date',
#  'relapse_third_type',
#  'relapse_fourth_date',
#  'relapse_fourth_type',
#  'relapse_fifth_date',
#  'relapse_fifth_type',
#  'relapse_sixth_date',
#  'relapse_sixth_type',
#  'relapse_seventh_date',
#  'relapse_seventh_type',
#  'relapse_eighth_date',
#  'relapse_eighth_type',
#  'relapse_ninth_date',
#  'relapse_ninth_type',
#  'relapse_tenth_date',
#  'relapse_tenth_type',
#  'relapse_history_complete',
#  'dmt_number',
#  'dmt_first',
#  'dmt_first_start',
#  'dmt_first_end',
#  'dmt_second',
#  'dmt_second_start',
#  'dmt_second_end',
#  'dmt_third',
#  'dmt_third_start',
#  'dmt_third_end',
#  'dmt_fourth',
#  'dmt_fourth_start',
#  'dmt_fourth_end',
#  'dmt_fifth',
#  'dmt_fifth_start',
#  'dmt_fifth_end',
#  'dmt_sixth',
#  'dmt_sixth_start',
#  'dmt_sixth_end',
#  'dmt_seventh',
#  'dmt_seventh_start',
#  'dmt_seventh_end',
#  'dmt_eighth',
#  'dmt_eighth_start',
#  'dmt_eighth_end',
#  'dmt_ninth',
#  'dmt_ninth_start',
#  'dmt_ninth_end',
#  'dmt_tenth',
#  'dmt_tenth_start',
#  'dmt_tenth_end',
#  'dmt_history_complete',
#  'mri_screening_complete',
#  'mri_screening_eligible',
#  'mri_scan_research',
#  'mri_scan_clinical',
#  'mri_consent_how',
#  'mri_date_electronic_sent',
#  'mri_date_mail_sent',
#  'mri_date_signed_consent',
#  'mri_version_consent_form',
#  'mri_version_date_consent_form',
#  'mri_consent_pdf',
#  't_mri_complete',
#  'tdate_order',
#  'tdate_completion',
#  'notes_3t',
#  'subtle_3t_mri_complete']

# %%
mainfile.head(20)
# Out:
#    id_participant         redcap_event_name name_first name_middle  \
# 0               1  consent_initial_vi_arm_1        NaN         NaN
# 1       PRT170001  consent_initial_vi_arm_1       Amar         NaN
# 2       PRT170002  consent_initial_vi_arm_1  Catherine           V
# 3       PRT170003  consent_initial_vi_arm_1       Lisa           A
# 4       PRT170004  consent_initial_vi_arm_1        Joe           A
# 5       PRT170005  consent_initial_vi_arm_1      Harry           M
# 6       PRT170006  consent_initial_vi_arm_1    Richard         NaN
# 7       PRT170007  consent_initial_vi_arm_1      Julie           A
# 8       PRT170008  consent_initial_vi_arm_1    Michele           M
# 9       PRT170009  consent_initial_vi_arm_1  Christine           S
# 10      PRT170010  consent_initial_vi_arm_1       Mary           T
# 11      PRT170011  consent_initial_vi_arm_1   Lizandra           S
# 12      PRT170012  consent_initial_vi_arm_1    William           P
# 13      PRT170013  consent_initial_vi_arm_1       Brad           G
# 14      PRT170014  consent_initial_vi_arm_1    Richard           S
# 15      PRT170015  consent_initial_vi_arm_1      Susan           M
# 16      PRT170016  consent_initial_vi_arm_1       Mary           L
# 17      PRT170017  consent_initial_vi_arm_1    JACQUIE         NaN
# 18      PRT170018  consent_initial_vi_arm_1       JAMI           B
# 19      PRT170019  consent_initial_vi_arm_1     ARLYNE         NaN
#
#      name_last         dob  subject_sex  race  ethnicity id_primary  ...  \
# 0          NaN         NaN          NaN   NaN        NaN        NaN  ...
# 1   Shiwlochan  1993-01-14          1.0   3.0        2.0  PRT170001  ...
# 2       Liadis  1950-02-23          2.0   4.0        2.0  PRT170002  ...
# 3   Stuczynski  1966-10-02          2.0   4.0        2.0  PRT170003  ...
# 4        Citro  1958-09-06          1.0   4.0        2.0  PRT170004  ...
# 5   Rubenstein  1959-06-13          1.0   4.0        2.0  PRT170005  ...
# 6         Paul  1968-03-05          1.0   4.0        2.0  PRT170006  ...
# 7       Higdon  1972-07-03          2.0   4.0        2.0  PRT170007  ...
# 8        Brown  1962-07-20          2.0   4.0        2.0  PRT170008  ...
# 9        Dietz  1959-06-04          2.0   4.0        2.0  PRT170009  ...
# 10   Briguglio  1951-09-25          2.0   4.0        2.0  PRT170010  ...
# 11      Wyland  1984-11-10          2.0   4.0        1.0  PRT170011  ...
# 12      Becker  1962-12-26          1.0   4.0        2.0  PRT170012  ...
# 13      Gavlik  1982-05-27          1.0   4.0        2.0  PRT170013  ...
# 14    Woodruff  1952-10-18          1.0   4.0       99.0  PRT170014  ...
# 15    Klingler  1956-08-10          2.0   4.0        2.0  PRT170015  ...
# 16     Fischer  1942-02-04          2.0   4.0        2.0  PRT170016  ...
# 17       OLSEN  1954-12-30          2.0   4.0        2.0  PRT170017  ...
# 18     CHIMILE  1977-03-08          2.0   4.0        2.0  PRT170018  ...
# 19     FENSTER  1941-12-27          2.0   4.0        2.0  PRT170019  ...
#
#    mri_date_mail_sent mri_date_signed_consent  mri_version_consent_form  \
# 0                 NaN                     NaN                       NaN
# 1                 NaN                     NaN                       NaN
# 2                 NaN                     NaN                       NaN
# 3                 NaN                     NaN                       NaN
# 4                 NaN                     NaN                       NaN
# 5                 NaN                     NaN                       NaN
# 6                 NaN                     NaN                       NaN
# 7                 NaN                     NaN                       NaN
# 8                 NaN                     NaN                       NaN
# 9                 NaN                     NaN                       NaN
# 10                NaN                     NaN                       NaN
# 11                NaN                     NaN                       NaN
# 12                NaN                     NaN                       NaN
# 13                NaN                     NaN                       NaN
# 14                NaN                     NaN                       NaN
# 15                NaN                     NaN                       NaN
# 16                NaN                     NaN                       NaN
# 17                NaN                     NaN                       NaN
# 18                NaN                     NaN                       NaN
# 19                NaN                     NaN                       NaN
#
#     mri_version_date_consent_form  mri_consent_pdf t_mri_complete  \
# 0                             NaN              NaN            NaN
# 1                             NaN              NaN            NaN
# 2                             NaN              NaN            NaN
# 3                             NaN              NaN            NaN
# 4                             NaN              NaN            NaN
# 5                             NaN              NaN            NaN
# 6                             NaN              NaN            NaN
# 7                             NaN              NaN            NaN
# 8                             NaN              NaN            NaN
# 9                             NaN              NaN            NaN
# 10                            NaN              NaN            NaN
# 11                            NaN              NaN            NaN
# 12                            NaN              NaN            NaN
# 13                            NaN              NaN            NaN
# 14                            NaN              NaN            NaN
# 15                            NaN              NaN            NaN
# 16                            NaN              NaN            NaN
# 17                            NaN              NaN            NaN
# 18                            NaN              NaN            NaN
# 19                            NaN              NaN            NaN
#
#     tdate_order tdate_completion  notes_3t  subtle_3t_mri_complete
# 0           NaN              NaN       NaN                     0.0
# 1           NaN              NaN       NaN                     0.0
# 2           NaN              NaN       NaN                     0.0
# 3           NaN              NaN       NaN                     0.0
# 4           NaN              NaN       NaN                     0.0
# 5           NaN              NaN       NaN                     0.0
# 6           NaN              NaN       NaN                     0.0
# 7           NaN              NaN       NaN                     0.0
# 8           NaN              NaN       NaN                     0.0
# 9           NaN              NaN       NaN                     0.0
# 10          NaN              NaN       NaN                     0.0
# 11          NaN              NaN       NaN                     0.0
# 12          NaN              NaN       NaN                     0.0
# 13          NaN              NaN       NaN                     0.0
# 14          NaN              NaN       NaN                     0.0
# 15          NaN              NaN       NaN                     0.0
# 16          NaN              NaN       NaN                     0.0
# 17          NaN              NaN       NaN                     0.0
# 18          NaN              NaN       NaN                     0.0
# 19          NaN              NaN       NaN                     0.0
#
# [20 rows x 502 columns]

# %%
mainfile.to_csv(output_pre + "promote_database.csv")
#mainfile.to_csv("promote_database.csv")

# %%
import pycurl
import io
from urllib.parse import urlencode

data = {
    'token': 'F9DD295357CE8FAC8062B80E85DF5063',
    'content': 'record',
    'format': 'csv',
    'type': 'flat',
    'rawOrLabel': 'raw',
    'rawOrLabelHeaders': 'raw',
    'exportCheckboxLabel': 'false',
    'exportSurveyFields': 'false',
    'exportDataAccessGroups': 'false',
    'returnFormat': 'json'
}

buf = io.BytesIO()
ch = pycurl.Curl()
ch.setopt(ch.URL, "https://www.ctsiredcap.pitt.edu/redcap/api/")

postfields = urlencode(data)
ch.setopt(ch.POSTFIELDS, postfields)
#ch.setopt(ch.POST, data.items())

ch.setopt(ch.WRITEFUNCTION, buf.write)
ch.perform()
ch.close()


body = buf.getvalue()
#print(body)
import pandas as pd
from io import StringIO

s=str(body,'utf-8')
data = StringIO(s) 
main = pd.read_csv(data)
main.to_csv(output_pre + "longitudinal.csv")
