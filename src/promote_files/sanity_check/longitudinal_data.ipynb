# %%
import numpy as np
import pandas as pd

# %%
input_pre = '../csv_files/input_files/'
output_pre = '../csv_files/output_files/' 
main = pd.read_csv(output_pre + 'promote_database.csv')
print(main.shape)
# Out:
# (2400, 466)
# C:\Users\ridhi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (33,119,121,182,184,223,226,230,231,233,236,237,241,245,263,264,278,298,299,302,394,436,438,439,441,452,453,455,456) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
long = pd.read_csv(input_pre + 'longitudinal.csv')
main = pd.read_csv(input_pre + 'main.csv')
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (4,8,14,23,26,27,31,33,34,38,42,77,100,119,142,171,172,197,199,201,205,211,215,217,219,221,241,243,246,249,252,255,258,264,273,276,279,282,346,357,359,371,462,463,467,470,471,472,595,597,600,606,612,621,627,630,633,636,643,647,651,655,699,713,715,784,786,798,878,879,884,923,935,939,1095,1099,1101,1103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\ridhi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (10,31,56,73,84,85,98,106,115,117,119,152,153,166,169,174,178,180,182,195,224,233,234,235,239,261,262,276,296,297,300,390,391,392,395,397,399,401,403,405,407,409,411,413,418,419,421,422,424,425,427,428,430,431,433,434,436,437,439,453,454,460,461) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
long.shape
# Out:
# (1545, 2305)

# %%
p_start = long.columns.get_loc("primary_questionnaire_timestamp")
print(p_start)
p_end = long.columns.get_loc("primary_questionnaire_complete") +1
print(p_end)
s_start = long.columns.get_loc("promote_self_reported_outcomes_timestamp")
print(s_start)
s_end = long.columns.get_loc("promote_self_reported_outcomes_complete")+1
print(s_end)
# Out:
# 18
# 171
# 171
# 462

# %%
id_series = list(long['id_participant_l'])
#list(id_series)

# %%
primary_df = long.iloc[:,p_start:p_end]
#primary_df.shape
primary_df['id_participant'] = id_series
primary_df.shape
# Out:
# (1545, 154)

# %%
self_df = long.iloc[:,s_start:s_end]
#primary_df.head()
self_df['id_participant'] = id_series

# %%
self_df.shape
#self_df['id_participant']
# Out:
# (1545, 292)

# %% [markdown]
# ###  Self Reported Questions

# %%
len(self_df[self_df['promote_self_reported_outcomes_complete']==2])
# Out:
# 94

# %%
#self_df[self_df['dmt_now']==2]
dmt_ref = {
    "dmtlist_now___1":"aubagio",
    "dmtlist_now___2":"avonex",
    "dmtlist_now___3":"betaseron",
    "dmtlist_now___4":"copaxone",
    "dmtlist_now___5":"extavia",
    "dmtlist_now___6":"gilenya",
    "dmtlist_now___7":"novantrone",
    "dmtlist_now___8":"plegridy",
    "dmtlist_now___9":"rebif",
    "dmtlist_now___10":"tecfidera",
    "dmtlist_now___11":"tysabri",
    "dmtlist_now___12":"other",
    "dmtlist_now___13":"rituxan",
    "dmtlist_now___14":"zinbryta",
    "dmtlist_now___15":"ocrevus",
    "dmtlist_now___16":"lemtrada",
}

# %%
import math
long.loc[long['dmt_now_tecfidera_duration'].isnull() == False, 'id_participant_l']
# Out:
# 292     PRT170209
# 964     PRT180699
# 1203    PRT190894
# 1209    PRT190900
# 1329    PRT191020
# 1334    PRT191025
# 1347    PRT191038
# Name: id_participant_l, dtype: object

# %%
for i, row in self_df.iterrows():
    a = row.dmt_now
    if a == 1 or a == 2:
        index = 1
        for i in range(12):
            col_name = 'dmtlist_now___' + str(i+1)
            if row[col_name] == 1:
                cols = []
                cols.append(col_name)
                for a in cols:
                    if a == "dmtlist_now___12":
                        print(row.dmt_now_other)
                    col_name2 = 'dmt_now_'+ dmt_ref[a] +'_duration'
                    if row[col_name2] == math.nan:
                        print(row.id_participant)
                    col_name3 = 'dmt_now_'+ dmt_ref[a] +'_start'
                    if row[col_name3] == math.nan:
                        print(row.id_participant)

# %%
dmtlist_ref = {
    "dmtlist_past___1":"aubagio",
    "dmtlist_past___2":"avonex",
    "dmtlist_past___3":"betaseron",
    "dmtlist_past___4":"copaxone",
    "dmtlist_past___5":"extavia",
    "dmtlist_past___6":"gilenya",
    "dmtlist_past___7":"novantrone",
    "dmtlist_past___8":"plegridy",
    "dmtlist_past___9":"rebif",
    "dmtlist_past___10":"tecfidera",
    "dmtlist_past___11":"tysabri",
    "dmtlist_past___12":"other",
    "dmtlist_past___13":"rituxan",
    "dmtlist_past___14":"zinbryta",
    "dmtlist_past___15":"ocrevus",
    "dmtlist_past___16":"lemtrada",
}

# %%
import math
for i, row in self_df.iterrows():
    a = row.dmt_past
    if a == 1 or a == 2:
        index = 1
        for i in range(12):
            col_name = 'dmtlist_past___' + str(i+1)
            if row[col_name] == 1:
                cols = []
                cols.append(col_name)
                for a in cols:
                    if a == "dmtlist_past___12":
                        print(row.dmt_past_other)
                        break
                    col_name2 = 'dmt_past_'+ dmtlist_ref[a] +'_duration'
                    if row[col_name2] == math.nan:
                        print(row.id_participant)
                    col_name3 = 'dmt_past_'+ dmtlist_ref[a] +'_start'
                    if col_name3 == 'dmt_past_copaxone_start': 
                        col_name3 = 'dmt_past_copaxon_start' 
                    if row[col_name3] == math.nan:
                        print(row.id_participant)
                    col_name4 = 'dmt_past_'+ dmtlist_ref[a] +'_stop'
                    if row[col_name3] == math.nan:
                        print(row.id_participant)
# Out:
# IVGA, PLAMSAMA PHESIS, CHEMO
# Ampyra
# nan

# %%
ex_start = self_df.columns.get_loc("dmt_now")
print(ex_start)
ex_end = self_df.columns.get_loc("dmt_past_zinbryta_stop") +1
print(ex_end)
# Out:
# 5
# 116

# %%
df = self_df.drop(self_df.iloc[:, 5:116], axis = 1)

# %%
df.describe()
# Out:
#           sex_sro  ms_category  ms_neurocare  fams4_mobility_gp3_familyneed  \
# count  113.000000    70.000000     78.000000                     111.000000
# mean     1.336283     4.000000      0.871795                       0.747748
# std      0.474541     1.251086      0.336482                       1.082661
# min      1.000000     1.000000      0.000000                       0.000000
# 25%      1.000000     3.000000      1.000000                       0.000000
# 50%      1.000000     4.000000      1.000000                       0.000000
# 75%      2.000000     4.000000      1.000000                       1.000000
# max      2.000000     7.000000      1.000000                       4.000000
#
#        fams4_mobility_gf1_work  fams4_mobility_an6_walking  \
# count               111.000000                  111.000000
# mean                  2.783784                    0.918919
# std                   1.497910                    1.280164
# min                   0.000000                    0.000000
# 25%                   2.000000                    0.000000
# 50%                   4.000000                    0.000000
# 75%                   4.000000                    2.000000
# max                   4.000000                    4.000000
#
#        fams4_mobility_itu3_social  fams4_mobility_cn55_legs  \
# count                  111.000000                111.000000
# mean                     0.936937                  2.693694
# std                      1.169921                  1.333436
# min                      0.000000                  0.000000
# 25%                      0.000000                  2.000000
# 50%                      0.000000                  3.000000
# 75%                      2.000000                  4.000000
# max                      4.000000                  4.000000
#
#        fams4_mobility_ms1_public  fams4_mobility_ms2_plan  ...     ltsu___3  \
# count                 110.000000               111.000000  ...  1138.000000
# mean                    0.727273                 1.207207  ...     0.007030
# std                     1.091326                 1.459247  ...     0.083586
# min                     0.000000                 0.000000  ...     0.000000
# 25%                     0.000000                 0.000000  ...     0.000000
# 50%                     0.000000                 1.000000  ...     0.000000
# 75%                     1.000000                 2.000000  ...     0.000000
# max                     4.000000                 4.000000  ...     1.000000
#
#           ltsu___4     ltsu___5     ltsu___6     ltsu___7  ltsu___8  \
# count  1138.000000  1138.000000  1138.000000  1138.000000    1138.0
# mean      0.002636     0.001757     0.007030     0.008787       0.0
# std       0.051299     0.041904     0.083586     0.093369       0.0
# min       0.000000     0.000000     0.000000     0.000000       0.0
# 25%       0.000000     0.000000     0.000000     0.000000       0.0
# 50%       0.000000     0.000000     0.000000     0.000000       0.0
# 75%       0.000000     0.000000     0.000000     0.000000       0.0
# max       1.000000     1.000000     1.000000     1.000000       0.0
#
#           ltsu___9     ltsu___0    ltsu___99  \
# count  1138.000000  1138.000000  1138.000000
# mean      0.007909     0.047452     0.005272
# std       0.088617     0.212696     0.072452
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000
#
#        promote_self_reported_outcomes_complete
# count                              1138.000000
# mean                                  0.167838
# std                                   0.552394
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   2.000000
#
# [8 rows x 174 columns]

# %%
complete_df = df[df['promote_self_reported_outcomes_complete']==2]
len(complete_df)
# Out:
# 94

# %%
nans = lambda complete_df: complete_df[complete_df.isnull().any(axis=1)]

# %%
nan_record = nans(complete_df)

# %%
nan_record.to_csv("promote_self_reported_outcomes_complete.csv")

# %% [markdown]
# ### Primary questionarrie

# %%
#list(primary_df)

# %%
complete_records_primary = primary_df[primary_df['primary_questionnaire_complete']==2]
len(complete_records_primary)
# Out:
# 94

# %%
nans = lambda complete_records_primary: complete_records_primary[complete_records_primary.isnull().any(axis=1)]

# %%
pdf = nans(complete_records_primary)

# %%
pdf.to_csv("primary_questionnaire_complete.csv")

# %%
u_start = long.columns.get_loc("dob_8e881e")
print(u_start)
u_end = long.columns.get_loc("update_questionnaire_complete")+1
print(u_end)
# Out:
# 461
# 876

# %%
update_df = long.iloc[:,u_start:u_end]
update_df['id_participant'] = id_series
update_df.shape
# Out:
# (1129, 416)

# %% [markdown]
# ### Food Frequency

# %%
f_start = long.columns.get_loc("dob_ffq")
print(f_start)
f_end = long.columns.get_loc("food_frequency_complete")+1
print(f_end)
# Out:
# 877
# 1104

# %%
food_df = long.iloc[:,f_start:f_end]
food_df['id_participant'] = id_series
food_df.shape
# Out:
# (1129, 228)

# %%
#list(food_df)

# %%
complete_records_food = food_df[food_df['food_frequency_complete']==2]
nans = lambda complete_records_food: complete_records_food[complete_records_food.isnull().any(axis=1)]
fdf = nans(complete_records_food)
fdf.to_csv("food_frequency_complete.csv")
len(complete_records_food)
# Out:
# 210

# %%
#list(long)

# %%
col_name = ['id_participant_l','id_med_record_number','dob','age_pq','sex_pq','subject_group','primary_questionnaire_complete',
            'promote_self_reported_outcomes_complete','update_questionnaire_complete','food_frequency_complete']

# %% [markdown]
# #### Starting for combine results

# %%
import math
for i, row in long.iterrows():
    a = row.dmt_past
    if a == 1 or a == 2:
        index = 1
        for i in range(12):
            col_name = 'dmtlist_past___' + str(i+1)
            if row[col_name] == 1:
                cols = []
                cols.append(col_name)
                for a in cols:
                    if a == "dmtlist_past___12":
                        print(row.dmt_past_other)
                        break
                    col_name2 = 'dmt_past_'+ dmtlist_ref[a] +'_duration'
                    if row[col_name2] == math.nan:
                        print(row.id_participant)
                    col_name3 = 'dmt_past_'+ dmtlist_ref[a] +'_start'
                    if col_name3 == 'dmt_past_copaxone_start': 
                        col_name3 = 'dmt_past_copaxon_start' 
                    if row[col_name3] == math.nan:
                        print(row.id_participant)
                    col_name4 = 'dmt_past_'+ dmtlist_ref[a] +'_stop'
                    if row[col_name3] == math.nan:
                        print(row.id_participant)
# Out:
# IVGA, PLAMSAMA PHESIS, CHEMO
# Ampyra

# %%
for i, row in self_df.iterrows():
    a = row.dmt_now
    if a == 1 or a == 2:
        index = 1
        for i in range(12):
            col_name = 'dmtlist_now___' + str(i+1)
            if row[col_name] == 1:
                cols = []
                cols.append(col_name)
                for a in cols:
                    if a == "dmtlist_now___12":
                        print(row.dmt_now_other)
                    col_name2 = 'dmt_now_'+ dmt_ref[a] +'_duration'
                    if row[col_name2] == math.nan:
                        print(row.id_participant)
                    col_name3 = 'dmt_now_'+ dmt_ref[a] +'_start'
                    if row[col_name3] == math.nan:
                        print(row.id_participant)

# %%
ex_start = long.columns.get_loc("dmt_now")
print(ex_start)
ex_end = long.columns.get_loc("dmt_past_zinbryta_stop") +1
print(ex_end)
# Out:
# 174
# 285

# %%
df_full = long.drop(long.iloc[:, 174:285], axis = 1)

# %%
complete_df = df_full[(df_full['promote_self_reported_outcomes_complete']==2) | (df_full['primary_questionnaire_complete']==2) 
                        |(df_full['food_frequency_complete']==2) | (df_full['update_questionnaire_complete']==2)]

# %%
complete_df
# Out:
#      id_participant_l redcap_event_name  redcap_survey_identifier  \
# 4           PRT170003     year_03_arm_2                       NaN
# 10          PRT170009     year_03_arm_2                       NaN
# 12          PRT170010     year_03_arm_2                       NaN
# 16          PRT170013     year_03_arm_2                       NaN
# 19          PRT170015     year_03_arm_2                       NaN
# 21          PRT170016     year_03_arm_2                       NaN
# 25          PRT170020     year_03_arm_2                       NaN
# 27          PRT170021     year_03_arm_2                       NaN
# 29          PRT170022     year_03_arm_2                       NaN
# 31          PRT170023     year_03_arm_2                       NaN
# 33          PRT170024     year_03_arm_2                       NaN
# 36          PRT170027     year_03_arm_2                       NaN
# 39          PRT170029     year_03_arm_2                       NaN
# 41          PRT170030     year_03_arm_2                       NaN
# 43          PRT170031     year_03_arm_2                       NaN
# 45          PRT170032     year_03_arm_2                       NaN
# 48          PRT170034     year_03_arm_2                       NaN
# 50          PRT170035     year_03_arm_2                       NaN
# 52          PRT170036     year_03_arm_2                       NaN
# 54          PRT170037     year_03_arm_2                       NaN
# 59          PRT170041     year_03_arm_2                       NaN
# 61          PRT170042     year_03_arm_2                       NaN
# 63          PRT170043     year_03_arm_2                       NaN
# 67          PRT170046     year_02_arm_2                       NaN
# 69          PRT170047     year_03_arm_2                       NaN
# 72          PRT170049     year_03_arm_2                       NaN
# 76          PRT170053     year_03_arm_2                       NaN
# 79          PRT170055     year_03_arm_2                       NaN
# 80          PRT170056     year_01_arm_1                       NaN
# 81          PRT170057     year_01_arm_1                       NaN
# ...               ...               ...                       ...
# 1054        PRT190944     year_01_arm_4                       NaN
# 1055        PRT190945     year_01_arm_4                       NaN
# 1056        PRT190946     year_01_arm_4                       NaN
# 1057        PRT190947     year_01_arm_4                       NaN
# 1058        PRT190948     year_01_arm_4                       NaN
# 1059        PRT190949     year_01_arm_4                       NaN
# 1060        PRT190950     year_01_arm_4                       NaN
# 1062        PRT190952     year_01_arm_4                       NaN
# 1063        PRT190953     year_01_arm_4                       NaN
# 1064        PRT190954     year_01_arm_4                       NaN
# 1065        PRT190955     year_01_arm_4                       NaN
# 1066        PRT190956     year_01_arm_4                       NaN
# 1067        PRT190957     year_01_arm_4                       NaN
# 1070        PRT190960     year_01_arm_4                       NaN
# 1076        PRT190966     year_01_arm_4                       NaN
# 1077        PRT190967     year_01_arm_4                       NaN
# 1079        PRT190969     year_01_arm_4                       NaN
# 1080        PRT190970     year_01_arm_4                       NaN
# 1081        PRT190971     year_01_arm_4                       NaN
# 1092        PRT190982     year_01_arm_4                       NaN
# 1093        PRT190983     year_01_arm_4                       NaN
# 1094        PRT190984     year_01_arm_4                       NaN
# 1100        PRT190990     year_01_arm_4                       NaN
# 1103        PRT190993     year_01_arm_4                       NaN
# 1104        PRT190994     year_01_arm_4                       NaN
# 1105        PRT190995     year_01_arm_4                       NaN
# 1106        PRT190996     year_01_arm_4                       NaN
# 1107        PRT190997     year_01_arm_4                       NaN
# 1113        PRT191003     year_01_arm_4                       NaN
# 1116        PRT191006     year_01_arm_4                       NaN
#
#        name_first         name_middle   name_last         dob         doe  \
# 4             NaN                 NaN         NaN         NaN         NaN
# 10            NaN                 NaN         NaN         NaN         NaN
# 12            NaN                 NaN         NaN         NaN         NaN
# 16            NaN                 NaN         NaN         NaN         NaN
# 19            NaN                 NaN         NaN         NaN         NaN
# 21            NaN                 NaN         NaN         NaN         NaN
# 25            NaN                 NaN         NaN         NaN         NaN
# 27            NaN                 NaN         NaN         NaN         NaN
# 29            NaN                 NaN         NaN         NaN         NaN
# 31            NaN                 NaN         NaN         NaN         NaN
# 33            NaN                 NaN         NaN         NaN         NaN
# 36            NaN                 NaN         NaN         NaN         NaN
# 1063                     NaN                                         NaN
# 1064                     NaN                                         NaN
# 1065                     NaN                                         NaN
# 1066                     NaN                                         NaN
# 1067                     NaN                                         NaN
# 1070                     NaN                                         NaN
# 1076                     NaN                                         NaN
# 1077                     NaN                                         NaN
# 1079                     NaN                                         NaN
# 1080                     NaN                                         NaN
# 1081                     NaN                                         NaN
# 1092                     NaN                                         NaN
# 1093                     NaN                                         NaN
# 1094                     NaN                                         NaN
# 1100                     NaN                                         NaN
# 1103                     NaN                                         NaN
# 1104                     NaN                                         NaN
# 1105                     NaN                                         NaN
# 1106                     NaN                                         NaN
# 1107                     NaN                                         NaN
# 1113                     NaN                                         NaN
# 1116                     NaN                                         NaN
#
# [365 rows x 1481 columns]

# %%
a1 = complete_df[['id_participant_l','id_med_record_number','dob','doe','subject_group','primary_questionnaire_complete',
            'promote_self_reported_outcomes_complete','update_questionnaire_complete','food_frequency_complete']]

# %%
a1
# Out:
#      id_participant_l  id_med_record_number         dob         doe  \
# 4           PRT170003                   NaN         NaN         NaN
# 10          PRT170009                   NaN         NaN         NaN
# 12          PRT170010                   NaN         NaN         NaN
# 16          PRT170013                   NaN         NaN         NaN
# 19          PRT170015                   NaN         NaN         NaN
# 21          PRT170016                   NaN         NaN         NaN
# 25          PRT170020                   NaN         NaN         NaN
# 27          PRT170021                   NaN         NaN         NaN
# 29          PRT170022                   NaN         NaN         NaN
# 31          PRT170023                   NaN         NaN         NaN
# 33          PRT170024                   NaN         NaN         NaN
# 36          PRT170027                   NaN         NaN         NaN
# 39          PRT170029                   NaN         NaN         NaN
# 41          PRT170030                   NaN         NaN         NaN
# 43          PRT170031                   NaN         NaN         NaN
# 45          PRT170032                   NaN         NaN         NaN
# 48          PRT170034                   NaN         NaN         NaN
# 50          PRT170035                   NaN         NaN         NaN
# 52          PRT170036                   NaN         NaN         NaN
# 54          PRT170037                   NaN         NaN         NaN
# 59          PRT170041                   NaN         NaN         NaN
# 61          PRT170042                   NaN         NaN         NaN
# 63          PRT170043                   NaN         NaN         NaN
# 67          PRT170046                   NaN         NaN         NaN
# 69          PRT170047                   NaN         NaN         NaN
# 72          PRT170049                   NaN         NaN         NaN
# 76          PRT170053                   NaN         NaN         NaN
# 79          PRT170055                   NaN         NaN         NaN
# 80          PRT170056                   NaN         NaN  2017-02-02
# 81          PRT170057                   NaN         NaN  2017-02-02
# ...               ...                   ...         ...         ...
# 1054        PRT190944                   NaN         NaN  2019-03-13
# 1055        PRT190945                   NaN         NaN  2019-03-13
# 1056        PRT190946                   NaN         NaN  2019-03-13
# 1057        PRT190947                   NaN         NaN  2019-03-13
# 1058        PRT190948                   NaN         NaN  2019-03-13
# 1059        PRT190949                   NaN         NaN  2019-03-13
# 1060        PRT190950                   NaN         NaN  2019-03-13
# 1062        PRT190952                   NaN         NaN  2019-04-05
# 1063        PRT190953                   NaN         NaN  2019-04-08
# 1064        PRT190954                   NaN         NaN  2019-04-08
# 1065        PRT190955                   NaN  1969-07-14  2019-04-10
# 21                                        NaN                            0.0
# 25                                        NaN                            2.0
# 27                                        NaN                            2.0
# 29                                        NaN                            2.0
# 31                                        NaN                            0.0
# 33                                        NaN                            2.0
# 36                                        NaN                            2.0
# 39                                        NaN                            2.0
# 41                                        NaN                            2.0
# 43                                        NaN                            2.0
# 45                                        NaN                            0.0
# 48                                        NaN                            2.0
# 50                                        NaN                            2.0
# 52                                        NaN                            2.0
# 54                                        NaN                            2.0
# 59                                        NaN                            2.0
# 61                                        NaN                            2.0
# 63                                        NaN                            2.0
# 67                                        NaN                            2.0
# 69                                        NaN                            2.0
# 72                                        NaN                            2.0
# 76                                        NaN                            2.0
# 79                                        NaN                            2.0
# 80                                        NaN                            2.0
# 81                                        NaN                            0.0
# ...                                       ...                            ...
# 1054                                      0.0                            NaN
# 1055                                      0.0                            NaN
# 1056                                      2.0                            NaN
# 1057                                      2.0                            NaN
# 1058                                      0.0                            NaN
# 1059                                      2.0                            NaN
# 1060                                      2.0                            NaN
# 1062                                      2.0                            NaN
# 1063                                      0.0                            NaN
# 1064                                      2.0                            NaN
# 1065                                      2.0                            NaN
# 1066                                      0.0                            NaN
# 1067                                      0.0                            NaN
# 1070                                      2.0                            NaN
# 1076                                      0.0                            NaN
# 1077                                      2.0                            NaN
# 1079                                      2.0                            NaN
# 1080                                      2.0                            NaN
# 1081                                      0.0                            NaN
# 1092                                      0.0                            NaN
# 1093                                      0.0                            NaN
# 1094                                      0.0                            NaN
# 1100                                      0.0                            NaN
# 1103                                      0.0                            NaN
# 1104                                      0.0                            NaN
# 1105                                      0.0                            NaN
# 1106                                      0.0                            NaN
# 1107                                      0.0                            NaN
# 1113                                      0.0                            NaN
# 1116                                      0.0                            NaN
#
#       food_frequency_complete
# 4                           2
# 10                          2
# 12                          2
# 16                          0
# 19                          0
# 21                          2
# 25                          2
# 27                          2
# 29                          2
# 31                          2
# 33                          2
# 36                          0
# 39                          2
# 41                          2
# 43                          2
# 45                          2
# 48                          0
# 50                          0
# 52                          2
# 54                          2
# 59                          2
# 61                          2
# 63                          0
# 67                          0
# 69                          2
# 72                          2
# 76                          2
# 79                          2
# 80                          2
# 81                          2
# ...                       ...
# 1054                        0
# 1055                        0
# 1056                        0
# 1057                        0
# 1058                        0
# 1059                        0
# 1060                        0
# 1062                        0
# 1063                        0
# 1064                        0
# 1065                        0
# 1066                        0
# 1067                        0
# 1070                        0
# 1076                        0
# 1077                        0
# 1079                        0
# 1080                        0
# 1081                        0
# 1092                        0
# 1093                        0
# 1094                        0
# 1100                        0
# 1103                        0
# 1104                        0
# 1105                        0
# 1106                        0
# 1107                        0
# 1113                        0
# 1116                        0
#
# [365 rows x 9 columns]

# %%
subject_group = {
    1:"MS",
    2:"Other related disorder",
    3:"Control",
}

# %%
complete = {
    0:"Incomplete",
    1:"Unverified",
    2:"Complete",
}

# %%
a1['primary_questionnaire_complete'] = a1['primary_questionnaire_complete'].map(complete)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a1['promote_self_reported_outcomes_complete'] = a1['promote_self_reported_outcomes_complete'].map(complete)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a1['update_questionnaire_complete'] = a1['update_questionnaire_complete'].map(complete)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a1['food_frequency_complete'] = a1['food_frequency_complete'].map(complete)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a1['subject_group'] = a1['subject_group'].map(subject_group)
# Out:
# C:\Users\ridhi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a1
# Out:
#      id_participant_l  id_med_record_number         dob         doe  \
# 4           PRT170003                   NaN         NaN         NaN
# 10          PRT170009                   NaN         NaN         NaN
# 12          PRT170010                   NaN         NaN         NaN
# 16          PRT170013                   NaN         NaN         NaN
# 19          PRT170015                   NaN         NaN         NaN
# 21          PRT170016                   NaN         NaN         NaN
# 25          PRT170020                   NaN         NaN         NaN
# 27          PRT170021                   NaN         NaN         NaN
# 29          PRT170022                   NaN         NaN         NaN
# 31          PRT170023                   NaN         NaN         NaN
# 33          PRT170024                   NaN         NaN         NaN
# 36          PRT170027                   NaN         NaN         NaN
# 39          PRT170029                   NaN         NaN         NaN
# 41          PRT170030                   NaN         NaN         NaN
# 43          PRT170031                   NaN         NaN         NaN
# 45          PRT170032                   NaN         NaN         NaN
# 48          PRT170034                   NaN         NaN         NaN
# 50          PRT170035                   NaN         NaN         NaN
# 52          PRT170036                   NaN         NaN         NaN
# 54          PRT170037                   NaN         NaN         NaN
# 59          PRT170041                   NaN         NaN         NaN
# 61          PRT170042                   NaN         NaN         NaN
# 63          PRT170043                   NaN         NaN         NaN
# 67          PRT170046                   NaN         NaN         NaN
# 69          PRT170047                   NaN         NaN         NaN
# 72          PRT170049                   NaN         NaN         NaN
# 76          PRT170053                   NaN         NaN         NaN
# 79          PRT170055                   NaN         NaN         NaN
# 80          PRT170056                   NaN         NaN  2017-02-02
# 81          PRT170057                   NaN         NaN  2017-02-02
# ...               ...                   ...         ...         ...
# 1054        PRT190944                   NaN         NaN  2019-03-13
# 1055        PRT190945                   NaN         NaN  2019-03-13
# 1056        PRT190946                   NaN         NaN  2019-03-13
# 1057        PRT190947                   NaN         NaN  2019-03-13
# 1058        PRT190948                   NaN         NaN  2019-03-13
# 1059        PRT190949                   NaN         NaN  2019-03-13
# 1060        PRT190950                   NaN         NaN  2019-03-13
# 1062        PRT190952                   NaN         NaN  2019-04-05
# 1063        PRT190953                   NaN         NaN  2019-04-08
# 1064        PRT190954                   NaN         NaN  2019-04-08
# 1065        PRT190955                   NaN  1969-07-14  2019-04-10
# 1066        PRT190956                   NaN         NaN  2019-04-10
# 1067        PRT190957                   NaN  1950-09-18  2019-04-11
# 1070        PRT190960                   NaN         NaN  2019-04-12
# 1076        PRT190966           841575322.0  1974-08-03  2019-04-17
# 1077        PRT190967           841780059.0  1944-11-26  2019-04-18
# 1079        PRT190969           842945069.0  1969-07-03  2019-04-19
# 1080        PRT190970           842243292.0  1984-07-01  2019-04-23
# 1081        PRT190971                   NaN  1984-09-08  2019-04-23
# 1092        PRT190982                   NaN         NaN  2019-04-29
# 1093        PRT190983           841122461.0  1979-02-18  2019-04-29
# 1094        PRT190984           841842304.0  1964-03-26  2019-04-29
# 1100        PRT190990                   NaN         NaN  2019-05-06
# 1103        PRT190993           842792814.0  1972-06-09  2019-05-09
# 1104        PRT190994            75649688.0  1955-01-06  2019-05-09
# 1105        PRT190995            84203979.0  1960-10-13  2019-05-10
# 1106        PRT190996                   NaN  1979-04-16  2019-05-10
# 1107        PRT190997                   NaN  1977-04-16  2019-05-10
# 1113        PRT191003           842243510.0  1973-11-22  2019-05-14
# 1116        PRT191006            75430616.0  1943-01-14  2019-05-15
#
#                subject_group primary_questionnaire_complete  \
# 4                        NaN                            NaN
# 10                       NaN                            NaN
# 12                       NaN                            NaN
# 16                       NaN                            NaN
# 19                       NaN                            NaN
# 21                       NaN                            NaN
# 25                       NaN                            NaN
# 27                       NaN                            NaN
# 29                       NaN                            NaN
# 31                       NaN                            NaN
# 33                       NaN                            NaN
# 36                       NaN                            NaN
# 39                       NaN                            NaN
# 41                       NaN                            NaN
# 43                       NaN                            NaN
# 45                       NaN                            NaN
# 48                       NaN                            NaN
# 50                       NaN                            NaN
# 52                       NaN                            NaN
# 54                       NaN                            NaN
# 59                       NaN                            NaN
# 61                       NaN                            NaN
# 63                       NaN                            NaN
# 67                       NaN                            NaN
# 69                       NaN                            NaN
# 72                       NaN                            NaN
# 76                       NaN                            NaN
# 79                       NaN                            NaN
# 80                   Control                            NaN
# 81                   Control                            NaN
# ...                      ...                            ...
# 1054                 Control                       Complete
# 1055                 Control                       Complete
# 1056                 Control                       Complete
# 1057                 Control                       Complete
# 1058                 Control                       Complete
# 1059                 Control                       Complete
# 1060                 Control                       Complete
# 1062                 Control                       Complete
# 1063                 Control                       Complete
# 1064                 Control                       Complete
# 1065                      MS                       Complete
# 1066                 Control                       Complete
# 1067                 Control                       Complete
# 1070                      MS                       Complete
# 1076                      MS                       Complete
# 1077                      MS                       Complete
# 1079                      MS                       Complete
# 1080  Other related disorder                       Complete
# 1081                      MS                       Complete
# 1092                 Control                       Complete
# 1093                      MS                       Complete
# 1094                      MS                       Complete
# 1100                 Control                       Complete
# 1103                      MS                       Complete
# 1104                      MS                       Complete
# 1105                      MS                       Complete
# 1106                      MS                       Complete
# 1107                 Control                       Complete
# 1113                      MS                       Complete
# 1116                      MS                       Complete
#
#      promote_self_reported_outcomes_complete update_questionnaire_complete  \
# 4                                        NaN                      Complete
# 10                                       NaN                      Complete
# 12                                       NaN                    Incomplete
# 16                                       NaN                      Complete
# 19                                       NaN                      Complete
# 21                                       NaN                    Incomplete
# 25                                       NaN                      Complete
# 27                                       NaN                      Complete
# 29                                       NaN                      Complete
# 31                                       NaN                    Incomplete
# 33                                       NaN                      Complete
# 36                                       NaN                      Complete
# 39                                       NaN                      Complete
# 41                                       NaN                      Complete
# 43                                       NaN                      Complete
# 45                                       NaN                    Incomplete
# 48                                       NaN                      Complete
# 50                                       NaN                      Complete
# 52                                       NaN                      Complete
# 54                                       NaN                      Complete
# 59                                       NaN                      Complete
# 61                                       NaN                      Complete
# 63                                       NaN                      Complete
# 67                                       NaN                      Complete
# 69                                       NaN                      Complete
# 72                                       NaN                      Complete
# 76                                       NaN                      Complete
# 79                                       NaN                      Complete
# 80                                       NaN                      Complete
# 81                                       NaN                    Incomplete
# ...                                      ...                           ...
# 1054                              Incomplete                           NaN
# 1055                              Incomplete                           NaN
# 1056                                Complete                           NaN
# 1057                                Complete                           NaN
# 1058                              Incomplete                           NaN
# 1059                                Complete                           NaN
# 1060                                Complete                           NaN
# 1062                                Complete                           NaN
# 1063                              Incomplete                           NaN
# 1064                                Complete                           NaN
# 1065                                Complete                           NaN
# 1066                              Incomplete                           NaN
# 1067                              Incomplete                           NaN
# 1070                                Complete                           NaN
# 1076                              Incomplete                           NaN
# 1077                                Complete                           NaN
# 1079                                Complete                           NaN
# 1080                                Complete                           NaN
# 1081                              Incomplete                           NaN
# 1092                              Incomplete                           NaN
# 1093                              Incomplete                           NaN
# 1094                              Incomplete                           NaN
# 1100                              Incomplete                           NaN
# 1103                              Incomplete                           NaN
# 1104                              Incomplete                           NaN
# 1105                              Incomplete                           NaN
# 1106                              Incomplete                           NaN
# 1107                              Incomplete                           NaN
# 1113                              Incomplete                           NaN
# 1116                              Incomplete                           NaN
#
#      food_frequency_complete
# 4                   Complete
# 10                  Complete
# 12                  Complete
# 16                Incomplete
# 19                Incomplete
# 21                  Complete
# 25                  Complete
# 27                  Complete
# 29                  Complete
# 31                  Complete
# 33                  Complete
# 36                Incomplete
# 39                  Complete
# 41                  Complete
# 43                  Complete
# 45                  Complete
# 48                Incomplete
# 50                Incomplete
# 52                  Complete
# 54                  Complete
# 59                  Complete
# 61                  Complete
# 63                Incomplete
# 67                Incomplete
# 69                  Complete
# 72                  Complete
# 76                  Complete
# 79                  Complete
# 80                  Complete
# 81                  Complete
# ...                      ...
# 1054              Incomplete
# 1055              Incomplete
# 1056              Incomplete
# 1057              Incomplete
# 1058              Incomplete
# 1059              Incomplete
# 1060              Incomplete
# 1062              Incomplete
# 1063              Incomplete
# 1064              Incomplete
# 1065              Incomplete
# 1066              Incomplete
# 1067              Incomplete
# 1070              Incomplete
# 1076              Incomplete
# 1077              Incomplete
# 1079              Incomplete
# 1080              Incomplete
# 1081              Incomplete
# 1092              Incomplete
# 1093              Incomplete
# 1094              Incomplete
# 1100              Incomplete
# 1103              Incomplete
# 1104              Incomplete
# 1105              Incomplete
# 1106              Incomplete
# 1107              Incomplete
# 1113              Incomplete
# 1116              Incomplete
#
# [365 rows x 9 columns]

# %%
old = pd.read_csv(input_pre + 'old.csv')

# %%
old
main_columns = list(old)
main_complete = [x for x in main_columns if 'complete' in x]

# %%
main_complete
# Out:
# ['primary_questionnaire_complete', 'promote_self_reported_outcomes_complete']

# %%
main_df = old[(old['promote_self_reported_outcomes_complete']==2) | (old['primary_questionnaire_complete']==2)]

# %%
a2 = main_df[['record_id','dob_pq','primary_questionnaire_complete','promote_self_reported_outcomes_complete']]

# %%
#new = pd.concat([a1, a2])

# %%
#new.to_csv("old_temp.csv")

# %%
a2
# Out:
#         record_id      dob_pq  primary_questionnaire_complete  \
